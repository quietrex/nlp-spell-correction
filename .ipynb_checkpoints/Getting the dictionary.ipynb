# %% [markdown]
# ### Importing libraries

# %%
# setting corpus directory
import os
from os import listdir
from os.path import isfile, join

# save into text file with json
import json

# spacy for tokenize document
import spacy
from collections import Counter

# Regular expression to remove puntuation.
import re

# Spacy to extract english texts
nlp = spacy.load("en")

# %%
# Load all the book part
def load_book(path):    
    input_file = os.path.join(path)
    with open(input_file) as f:
        chapter = f.read()
    return chapter

# %%
# Collect all of the chapters file names
path = './book/'
chapter_files = [f for f in listdir(path) if isfile(join(path, f))]

# %%
chapter_files
# Out:
# ['chapter - 1.txt',
#  'chapter - 11.txt',
#  'chapter - 12.txt',
#  'chapter - 14.txt',
#  'chapter - 2.txt',
#  'chapter - 3.txt',
#  'chapter - 4.txt',
#  'chapter - 6.txt',
#  'chapter - 7.txt']

# %%
# Load the book using the file names
chapters = []
for chapter in chapter_files:
    chapters.append(load_book(path+chapter))

# %%
# Getting number of words in each chapter from the book 
total_word = 0
for i in range(len(chapters)):
    print("The number of {} words in chapter of named {}.".format(len(chapters[i].split()), chapter_files[i]))
    total_word += len(chapters[i].split())
# Out:
# The number of 13815 words in chapter of named chapter - 1.txt.
# The number of 11523 words in chapter of named chapter - 11.txt.
# The number of 13084 words in chapter of named chapter - 12.txt.
# The number of 18405 words in chapter of named chapter - 14.txt.
# The number of 6936 words in chapter of named chapter - 2.txt.
# The number of 13542 words in chapter of named chapter - 3.txt.
# The number of 11964 words in chapter of named chapter - 4.txt.
# The number of 11951 words in chapter of named chapter - 6.txt.
# The number of 11207 words in chapter of named chapter - 7.txt.

# %%
print("The total of {} words in the corpus.".format(total_word))
# Out:
# The total of 112427 words in the corpus.

# %%
# Getting part 1
with open('book\\chapter - 1.txt', 'r') as reader:
    chapter_1 = reader.read()

with open('book\\chapter - 2.txt', 'r') as reader:
    chapter_2 = reader.read()

with open('book\\chapter - 3.txt', 'r') as reader:
    chapter_3 = reader.read()

with open('book\\chapter - 4.txt', 'r') as reader:
    chapter_4 = reader.read()

# %%
# Getting part 2
with open('book\\chapter - 6.txt', 'r') as reader:
    chapter_6 = reader.read()

with open('book\\chapter - 7.txt', 'r') as reader:
    chapter_7 = reader.read()

# %%
# Getting part 3
with open('book\\chapter - 11.txt', 'r') as reader:
    chapter_11 = reader.read()

with open('book\\chapter - 12.txt', 'r') as reader:
    chapter_12 = reader.read()

# %%
# Getting part 4
with open('book\\chapter - 14.txt', 'r') as reader:
    chapter_14 = reader.read()

# %% [markdown]
# ### Splitting corpus into train ratio of 0.60, validation ratio of 0.20 and testing ratio with 0.20
# train_ratio = 0.60;
# validation_ratio = 0.20;
# test_ratio = 0.20
#
# 1. chapter 1 - 13815
# Training set - 8289 (60%)
# Validation set - 2763 (20%)
# Test set - 2763 (20%)
#
# 2. chapter 2 - 6936
# training set - 4162 (60%)
# validation set - 1387 (20%)
# test set - 1387 (20%)
#
# 3. chapter 3 - 13542
# Training set - 8125 (60%)
# Validation set - 2708 (20%)
# Test set - 2708 (20%)
#
# 4. chapter 4 - 11964
# Training set - 7178 (60%)
# Validation set - 2393 (20%)
# Test set - 2393 (20%)
#
#
# 5. chapter 6 - 11951
# Training set - 7171 (60%)
# Validation set - 2390 (20%)
# Test set - 2390 (20%)
#
# 6. chapter 7 - 11207
# Training set - 6725 (60%)
# Validation set - 2241 (20%)
# Test set - 2241 (20%)
#
#
# 7. chapter 11 - 11523
# Training set - 6914 (60%)
# Validation set - 2763 (20%)
# Test set - 2763 (20%)
#
# 8. chapter 12 - 13084
# Training set - 7850 (60%)
# Validation set - 2617 (20%)
# Test set - 2617 (20%)
#
#
# 9. chapter 14 - 18405
# Training set - 11043 (60%)
# Validation set - 3681 (20%)
# Test set - 3681 (20%)
#
#
# 5. Merging all training set into trainingset.txt, validation set into validation.txt, and testing set into test.txt

# %%
train_ratio = 0.60
validation_ratio = 0.20
test_ratio = 0.20

# %%
with open('training_data\\training set.txt', 'r') as reader:
    train_set = reader.read()
    
with open('training_data\\validation set.txt', 'r') as reader:
    validation_set = reader.read()
    
with open('training_data\\testing set.txt', 'r') as reader:
    testing_set = reader.read()

# %%
print("Training set has approximately " + str(len(train_set.split(" "))) + " words.")
print("Validation set has approximately " + str(len(validation_set.split(" "))) + " words.")
print("Testing set has approximately " + str(len(testing_set.split(" "))) + " words.")
# Out:
# Training set has approximately 67130 words.
# Validation set has approximately 22064 words.
# Testing set has approximately 23298 words.

# %% [markdown]
# ### Creating dictionary (to get frequency) for training set, validation set and testing set

# %% [markdown]
# #### Remove puntuation (i.e. !.?)

# %%
def remove_punctuation(pattern,phrase):
    for pat in pattern:
        return(re.findall(pat,phrase))
        return('\n')
            
# Capturing pattern like .!?
pattern=['[^!.?]+']

# %%
train_set = "".join(remove_punctuation(pattern,train_set))
validation_set = "".join(remove_punctuation(pattern,validation_set))
testing_set = "".join(remove_punctuation(pattern,testing_set))

# %% [markdown]
# #### Word Tokenize in SpaCy
# This step is similar to previous procedure to remove puntuation, but this is in tokenize format, texts may not be removed completely without word tokenization.
# Texts will empty strings will also be removed in this step.

# %%
# Training set
doc_train_set = nlp(train_set)
tokenzie_texts_trainset = [token.text for token in doc_train_set]

# Validation set
doc_validation_set = nlp(validation_set)
tokenzie_texts_validation_set = [token.text for token in doc_validation_set]

# Testing set
doc_test_set = nlp(testing_set)
tokenzie_texts_test_set = [token.text for token in doc_test_set]

# %%
print(tokenzie_texts_trainset)
# Out:
# ['the', 'potential', 'for', 'psychologists', 'to', 'assist', 'the', 'legal', 'system', 'has', 'been', 'recognized', 'since', 'the', 'early', 'twentieth', 'century', ',', 'but', 'only', 'within', 'the', 'past', 'fifty', 'years', 'has', 'psychology', 'begun', 'to', 'realize', 'this', 'potential', 'in', 'meaningful', 'ways', ' ', 'this', 'progress', 'has', 'included', 'newly', 'developed', 'professional', 'organizations', ',', 'such', 'as', 'the', 'american', 'psychology', 'law', 'society', 'and', 'the', 'international', 'association', 'for', 'correctional', 'and', 'forensic', 'psychology', ';', 'graduate', ',', 'internship', ',', 'and', 'fellowship', 'programs', 'in', 'the', 'specialty', 'area', ';', 'organizations', 'devoted', 'to', 'certifying', 'qualified', 'practitioners', ',', 'such', 'as', 'the', 'american', 'board', 'of', 'forensic', 'psychology', 'and', 'the', 'american', 'board', 'of', 'police', 'and', 'public', 'safety', 'psychology', ';', 'such', 'scientific', 'journals', 'as', 'law', 'and', 'human', 'behavior', ',', 'behavioral', 'sciences', 'and', 'the', 'law', ',', 'and', 'criminal', 'justice', 'and', 'behavior', ';', 'and', 'books', 'devoted', 'to', 'the', 'interface', 'of', 'psychology', 'and', 'law', ' ', 'this', 'specialty', 'area', 'has', 'continued', 'to', 'grow', 'rapidly', 'since', 'the', 'previous', 'edition', 'of', 'the', 'handbook', 'of', 'forensic', 'psychology', 'was', 'published', 'in', 'two', 'thousand', 'and', 'six', ',', 'with', 'increasing', 'numbers', 'of', 'psychologists', 'becoming', 'involved', 'in', 'forensic', 'practice', 'and', 'research', 'and', 'a', 'steady', 'flow', 'of', 'new', 'ideas', 'and', 'information', 'becoming', 'available', ' ', 'chapters', 'nineteen', 'and', 'twenty', 'then', 'provide', 'accounts', 'of', 'the', 'development', 'of', 'lie', 'detection', 'and', 'hypnosis', 'and', 'describe', 'current', 'and', 'emerging', 'trends', 'in', 'forensic', 'uses', 'of', 'these', 'procedures', ' ', 'part', 'five', 'of', 'the', 'handbook', 'looks', 'at', 'effective', 'communication', 'of', 'expert', 'opinion', 'in', 'forensic', 'cases', ' ', 'chapter', 'twenty', 'one', 'focuses', 'on', 'the', 'essentials', 'of', 'writing', 'appropriate', 'and', 'useful', 'reports', ',', 'and', 'chapter', 'twenty', 'two', 'discusses', 'the', 'admissibility', 'of', 'expert', 'testimony', 'and', 'key', 'considerations', 'in', 'communicating', 'one', 'work', 'and', 'opinions', 'to', 'legal', 'decision', 'makers', ' ', 'part', 'six', 'concludes', 'the', 'handbook', 'with', 'consideration', 'of', 'some', 'important', 'aspects', 'of', 'providing', 'services', 'to', 'offenders', ' ', 'chapter', 'twenty', 'three', 'discusses', 'principles', 'of', 'effective', 'correctional', 'rehabilitation', 'in', 'both', 'prison', 'settings', 'and', 'the', 'community', ',', 'and', 'chapter', 'twenty', 'four', 'provides', 'a', 'behind', '-', 'the', '-', 'bars', 'guide', 'to', 'conducting', 'psychotherapy', 'with', 'offenders', ' ', 'chapter', 'twenty', 'five', 'continues', 'this', 'theme', 'with', 'specific', 'attention', 'to', 'diagnostic', 'and', 'treatment', 'procedures', 'useful', 'in', 'working', 'with', 'sexual', 'offenders', ' ', 'finally', ',', 'the', 'appendix', 'provides', 'readers', 'with', 'the', 'full', 'text', 'of', 'the', 'specialty', 'guidelines', 'for', 'forensic', 'psychology', ' ', 'we', 'would', 'like', 'to', 'thank', 'our', 'authors', 'for', 'their', 'valuable', 'contributions', 'to', 'this', 'volume', ',', 'both', 'those', 'who', 'revised', 'chapters', 'that', 'appeared', 'in', 'previous', 'editions', 'and', 'those', 'who', 'joined', 'us', 'for', 'the', 'first', 'time', 'in', 'this', 'edition', ' ', 'we', 'also', 'want', 'to', 'acknowledge', 'with', 'appreciation', 'the', 'guidance', 'and', 'support', 'of', 'the', 'john', 'wiley', 'and', 'sons', 'editorial', 'staff', ',', 'particularly', 'patricia', 'rossi', ',', 'executive', 'editor', 'and', 'kara', 'borbely', ',', 'editorial', 'program', 'coordinator', ' ', ...

# %%
print(tokenzie_texts_validation_set)
# Out:
# ['chapter', 'five', 'describes', 'training', 'models', 'and', 'resources', 'in', 'forensic', 'psychology', 'for', 'faculty', 'developing', 'programs', 'of', 'instruction', 'and', 'for', 'students', 'and', 'general', 'practitioners', 'seeking', 'specialized', 'education', 'or', 'supervised', 'experience', 'in', 'forensic', 'psychology', ' ', 'part', 'two', 'comprises', 'five', 'chapters', 'concerning', 'applications', 'of', 'psychology', 'in', 'civil', 'proceedings', ' ', 'chapter', 'six', 'addresses', 'family', 'law', 'procedures', 'and', 'issues', 'related', 'to', 'conducting', 'evaluations', 'of', 'children', 'and', 'their', 'parents', 'involved', 'in', 'disputed', 'custody', ' ', 'chapter', 'twelve', 'traces', 'the', 'development', 'and', 'current', 'applications', 'of', 'the', 'concepts', 'of', 'criminal', 'responsibility', 'and', 'legal', 'insanity', ' ', 'chapter', 'thirteen', 'delineates', 'the', 'related', 'nuances', 'of', 'criminal', 'intent', 'and', 'diminished', 'capacity', ' ', 'part', 'four', 'presents', 'information', 'on', 'seven', 'special', 'applications', 'of', 'forensic', 'psychology', ' ', 'chapter', 'fourteen', 'leads', 'off', 'with', 'a', 'discussion', 'of', 'violence', 'risk', 'research', 'and', 'assessment', ',', 'and', 'chapter', 'fifteen', 'follows', 'with', 'an', 'overview', 'of', 'emerging', 'roles', 'for', 'psychologists', 'in', 'law', 'enforcement', ' ', 'chapter', 'sixteen', 'reviews', 'considerations', 'related', 'to', 'evaluating', 'jury', 'decision', 'making', 'and', 'promoting', 'juror', 'competence', ' ', 'chapters', 'seventeen', 'and', 'eighteen', 'review', 'developments', 'related', 'to', 'the', 'evaluation', 'of', 'testimony', 'given', 'by', 'adults', 'and', 'children', ' ', 'on', 'the', 'whole', ',', 'however', ',', 'developments', 'from', 'the', 'nineteen', 'eighties', 'forward', 'are', 'addressed', 'in', 'the', 'works', 'of', 'other', 'contributors', 'to', 'this', 'handbook', ' ', 'legal', 'psychology', ' ', 'legal', 'psychology', 'refers', 'to', 'psychological', 'theory', ',', 'research', ',', 'and', 'practice', 'directly', 'pertinent', 'to', 'the', 'law', 'and', 'legal', 'issues', ' ', 'do', 'horses', 'in', 'the', 'field', 'stand', 'with', 'head', 'or', 'tail', 'to', 'the', 'wind', ' ', 'in', 'which', 'direction', 'do', 'the', 'seeds', 'of', 'an', 'apple', 'point', ' ', 'what', 'was', 'the', 'weather', 'one', 'week', 'ago', 'today', ' ', 'when', 'mckeen', 'cattell', 'posed', 'these', 'questions', 'to', 'fifty', 'six', 'college', 'students', 'at', 'columbia', 'university', 'in', 'march', 'eighteen', 'ninety', 'three', ',', 'he', 'was', 'probably', 'conducting', 'one', 'of', 'the', 'first', 'american', 'studies', ',', 'albeit', 'an', 'informal', 'one', ',', 'on', 'the', 'psychology', 'of', 'testimony', ' ', 'the', 'questions', 'he', 'asked', 'his', 'students', 'were', 'similar', 'to', 'those', 'that', 'might', 'naturally', 'be', 'asked', 'in', 'a', 'court', 'of', 'justice', ' ', 'as', 'we', 'will', 'see', 'shortly', ',', 'both', 'french', 'and', 'german', 'psychologists', 'were', 'familiar', 'with', 'the', 'powerful', 'influence', 'of', 'suggestion', 'over', 'sensation', 'and', 'perception', ',', 'having', 'conducted', 'substantial', 'research', 'in', 'these', 'areas', ' ', 'the', 'specific', 'conditions', 'under', 'which', 'testimony', 'was', 'inaccurate', 'were', 'not', 'known', ',', 'however', ' ', 'cattell', 'noted', ':', 'an', 'unscrupulous', 'attorney', 'can', 'discredit', 'the', 'statements', 'of', 'a', 'truthful', 'witness', 'by', 'cunningly', 'selected', 'questions', ' ', 'first', ',', 'alfred', 'binet', 'replicated', 'cattell', 'project', 'in', 'france', ' ', 'in', 'addition', ',', 'he', 'summarized', 'relevant', 'experiments', 'on', 'the', 'psychology', 'of', 'testimony', 'that', 'were', 'being', 'conducted', 'in', 'europe', ',', 'and', 'he', 'eventually', 'called', 'for', 'a', 'science', 'psychojudiciaire', ' ', 'stern', 'and', 'liszt', 'conducted', 'a', 'reality', 'experim ...

# %%
print(tokenzie_texts_test_set)
# Out:
# ['this', 'fourth', 'edition', 'of', 'the', 'handbook', 'of', 'forensic', 'psychology', ',', 'like', 'its', 'predecessors', ',', 'aims', 'to', 'provide', 'an', 'authoritative', 'and', 'comprehensive', 'resource', 'for', 'understanding', 'the', 'theoretical', 'foundations', 'of', 'forensic', 'psychology', ',', 'becoming', 'familiar', 'with', 'the', 'expanding', 'research', 'base', 'in', 'this', 'specialty', ',', 'and', 'learning', 'to', 'apply', 'forensic', 'concepts', 'artfully', 'in', 'everyday', 'practice', ' ', 'to', 'this', 'end', ',', 'the', 'contributors', 'to', 'this', 'volume', ',', 'as', 'in', 'the', 'prior', 'three', 'editions', ',', 'are', 'accomplished', 'scholars', 'and', 'practitioners', 'in', 'their', 'respective', 'areas', ' ', 'some', 'are', 'prominent', 'academicians', 'who', 'conduct', 'research', 'and', 'offer', 'consultation', ' ', 'others', 'are', 'actively', 'engaged', 'service', 'providers', 'who', 'also', 'make', 'significant', 'contributions', 'to', 'the', 'literature', ' ', 'several', 'have', 'degrees', 'in', 'law', 'as', 'well', 'as', 'psychology', ' ', 'these', 'authors', 'were', 'asked', 'to', 'delineate', 'the', 'enduring', 'issues', 'in', 'an', 'area', 'of', 'their', 'specialty', 'and', 'frame', 'these', 'issues', 'in', 'the', 'light', 'of', 'contemporary', 'research', 'and', 'prevailing', 'conceptual', 'formations', ' ', 'although', 'similar', 'in', 'focus', 'and', 'structure', 'to', 'previous', 'editions', ',', 'the', 'present', 'volume', 'has', 'been', 'substantially', 'rewritten', 'and', 'updated', 'to', 'enhance', 'its', 'value', ' ', 'the', 'content', 'and', 'sequence', 'of', 'the', 'chapters', 'have', 'been', 'reframed', 'to', 'increase', 'their', 'relevance', 'to', 'the', 'practice', 'of', 'forensic', 'psychology', 'and', 'encompass', 'both', 'recent', 'research', 'findings', 'and', 'developments', 'in', 'statutory', 'and', 'case', 'law', ' ', 'as', 'testimony', 'to', 'the', 'fresh', 'perspectives', 'in', 'this', 'fourth', 'edition', ',', 'the', 'table', 'of', 'contents', 'identifies', 'forty', 'eight', 'authors', 'and', 'coauthors', ',', 'of', 'whom', 'twenty', 'four', 'are', 'new', 'contributors', 'to', 'the', 'handbook', ' ', 'the', 'present', 'volume', 'comprises', 'six', 'parts', ' ', 'part', 'one', 'concerns', 'the', 'context', 'of', 'forensic', 'psychology', 'and', 'begins', 'with', 'chapters', 'on', 'the', 'history', 'of', 'forensic', 'psychology', 'and', 'on', 'defining', 'the', 'nature', 'of', 'forensic', 'psychology', ' ', 'chapter', 'three', 'then', 'provides', 'information', 'about', 'and', 'guidelines', 'for', 'accessing', 'the', 'legal', 'literature', ' ', 'chapter', 'four', 'alerts', 'forensic', 'psychologists', 'to', 'ethical', 'and', 'legal', 'considerations', 'that', 'should', 'guide', 'their', 'work', ',', 'with', 'specific', 'attention', 'to', 'the', 'american', 'psychological', 'association', 'ethics', 'code', 'and', 'the', 'specialty', 'guidelines', 'for', 'forensic', 'psychology', ' ', 'chapter', 'seven', 'discusses', 'personal', 'injury', 'litigation', ',', 'with', 'particular', 'attention', 'to', 'considerations', 'in', 'psychological', 'assessment', ' ', 'chapter', 'eight', 'reviews', 'the', 'impact', 'of', 'recent', 'congressional', 'legislation', 'on', 'identifying', 'and', 'treating', 'educational', 'disabilities', ' ', 'chapter', 'nine', 'examines', 'issues', 'related', 'to', 'the', 'assessment', 'of', 'persons', 'competence', 'to', 'execute', 'a', 'variety', 'of', 'legal', 'rights', 'in', 'civil', 'contexts', ' ', 'chapter', 'ten', 'concludes', 'this', 'section', 'with', 'guidelines', 'for', 'conducting', 'evaluations', 'in', 'cases', 'of', 'alleged', 'child', 'abuse', 'or', 'neglect', ' ', 'part', 'three', 'deals', 'with', 'applying', 'psychology', 'in', 'criminal', 'proceedings', 'and', 'covers', 'three', 'critical', 'considerations', 'of', 'concern', 'to', 'triers', 'of', 'fact', ' ', 'chapter', 'eleven', 'provides', 'guidelines', 'for', 'assessing', 'co ...

# %% [markdown]
# #### Remove puntuation to get frequency distribution

# %%
nonPunct = re.compile('.*[A-Za-z0-9].*')

# trainset
filtered_texts_trainset = [w for w in tokenzie_texts_trainset if nonPunct.match(w)]
counts_train_set = Counter(filtered_texts_trainset)

# validation set
filtered_texts_validation_set = [w for w in tokenzie_texts_validation_set if nonPunct.match(w)]
counts_validation_set = Counter(filtered_texts_validation_set)

# test set
filtered_texts_testset = [w for w in tokenzie_texts_test_set if nonPunct.match(w)]
counts_test_set = Counter(filtered_texts_testset)

# %%
counts_train_set
# Out:
# Counter({'the': 4081,
#          'potential': 36,
#          'for': 598,
#          'psychologists': 200,
#          'to': 1835,
#          'assist': 33,
#          'legal': 284,
#          'system': 89,
#          'has': 170,
#          'been': 169,
#          'recognized': 7,
#          'since': 22,
#          'early': 34,
#          'twentieth': 10,
#          'century': 16,
#          'but': 121,
#          'only': 71,
#          'within': 35,
#          'past': 24,
#          'fifty': 25,
#          'years': 35,
#          'psychology': 176,
#          'begun': 3,
#          'realize': 1,
#          'this': 354,
#          'in': 1528,
#          'meaningful': 7,
#          'ways': 25,
#          'progress': 8,
#          'included': 21,
#          'newly': 2,
#          'developed': 33,
#          'professional': 65,
#          'organizations': 10,
#          'such': 151,
#          'as': 526,
#          'american': 32,
#          'law': 234,
#          'society': 12,
#          'and': 1952,
#          'international': 4,
#          'association': 14,
#          'correctional': 32,
#          'forensic': 231,
#          'graduate': 4,
#          'internship': 5,
#          'fellowship': 1,
#          'programs': 13,
#          'specialty': 28,
#          'area': 26,
#          'devoted': 9,
#          'certifying': 1,
#          'qualified': 7,
#          'practitioners': 26,
#          'board': 10,
#          'of': 2305,
#          'police': 53,
#          'public': 27,
#          'safety': 3,
#          'scientific': 18,
#          'journals': 11,
#          'human': 8,
#          'behavior': 41,
#          'behavioral': 11,
#          'sciences': 3,
#          'criminal': 92,
#          'justice': 28,
#          'books': 13,
#          'interface': 2,
#          'continued': 12,
#          'grow': 1,
#          'rapidly': 2,
#          'previous': 12,
#          'edition': 6,
#          'handbook': 8,
#          'was': 255,
#          'published': 28,
#          'two': 89,
#          'thousand': 24,
#          'six': 29,
#          'with': 428,
#          'increasing': 4,
#          'numbers': 2,
#          'becoming': 10,
#          'involved': 29,
#          'practice': 58,
#          'research': 148,
#          'a': 1163,
#          'steady': 2,
#          'flow': 2,
#          'new': 34,
#          'ideas': 4,
#          'information': 150,
#          'available': 39,
#          'chapters': 2,
#          'nineteen': 117,
#          'twenty': 62,
#          'then': 36,
#          'provide': 85,
#          'accounts': 6,
#          'development': 19,
#          'lie': 4,
#          'detection': 2,
#          'hypnosis': 1,
#          'describe': 14,
#          'current': 22,
#          'emerging': 2,
#          'trends': 5,
#          'uses': 3,
#          'these': 214,
#          'procedures': 31,
#          'part': 24,
#          'five': 43,
#          'looks': 2,
#          'at': 183,
#          'effective': 12,
#          'communication': 7,
#          'expert': 118,
#          'opinion': 39,
#          'cases': 117,
#          'chapter': 34,
#          'one': 192,
#          'focuses': 7,
#          'on': 373,
#          'essentials': 2,
#          'writing': 10,
#          'appropriate': 23,
#          'useful': 28,
#          'reports': 23,
#          'discusses': 3,
#          'admissibility': 3,
#          'testimony': 63,
#          'key': 12,
#          'considerations': 10,
#          'communicating': 1,
#          'work': 57,
#          'opinions': 51,
#          'decision': 80,
#          'makers': 9,
#          'concludes': 1,
#          'consideration': 17,
#          'some': 128,
#          'important': 76,
#          'aspects': 13,
#          'providing': 29,
#          'services': 49,
#          'offenders': 31,
#          'three': 63,
#          'principles': 15,
#          'rehabilitation': 7,
#          'both': 79,
#          'prison': 18,
#          'settings': 13,
#          'community': 22,
#          'four': 60,
#          'provides': 30,
#          'behind': 3,
#          'bars': 1,
#          'guide': 10,
#          'conducting': 40,
#          'psychotherapy': 4,
#          'continues': 2,
#          'theme': 1,
#          'specific': 63,
#          'attention': 20,
#          'diagnostic': 11,
#          'treatment': 60,
#          'working': 15,
#          'sexual': 19,
#          'finally': 18,
#          'appendix': 1,
#          'readers': 6,
#          'full': 9,
#          'text': 4,
#          'guidelines': 53,
#          'we': 86,
#          'would': 90,
#          'like': 33,
#          'thank': 1,
#          'our': 15,
#          'authors': 21,
#          'their': 324,
#          'valuable': 8,
#          'contributions': 12,
#          'volume': 5,
#          'those': 68,
#          'who': 132,
#          'revised': 12,
#          'that': 921,
#          'appeared': 3,
#          'editions': 5,
#          'joined': 3,
#          'us': 38,
#          'first': 81,
#          'time': 62,
#          'also': 94,
#          'want': 7,
#          'acknowledge': 3,
#          'appreciation': 5,
#          'guidance': 8,
#          'support': 32,
#          'john': 2,
#          'wiley': 1,
#          'sons': 1,
#          'editorial': 2,
#          'staff': 5,
#          'particularly': 21,
#          'patricia': 1,
#          'rossi': 1,
#          'executive': 4,
#          'editor': 2,
#          'kara': 1,
#          'borbely': 1,
#          'program': 6,
#          'coordinator': 5,
#          'recognize': 8,
#          'honor': 1,
#          'colleague': 3,
#          'allen': 1,
#          'hess': 2,
#          'served': 6,
#          'coeditor': 1,
#          'before': 34,
#          'his': 126,
#          'untimely': 1,
#          'death': 9,
#          'familiar': 11,
#          'will': 114,
#          'fingerprints': 1,
#          'well': 65,
#          'course': 17,
#          'over': 36,
#          'have': 243,
#          'learned': 6,
#          'few': 22,
#          'lessons': 2,
#          'asserted': 4,
#          'do': 66,
#          'not': 368,
#          'care': 11,
#          'about': 172,
#          'history': 47,
#          'profession': 10,
#          'are': 397,
#          'instead': 10,
#          'drawn': 6,
#          'contemporary': 9,
#          'issues': 80,
#          'theories': 7,
#          'simplistic': 1,
#          'generalization': 1,
#          'so': 35,
#          'subsequent': 10,
#          'acknowledged': 3,
#          'initial': 9,
#          'statement': 10,
#          'had': 73,
#          'rash': 1,
#          'is': 748,
#          'apparent': 3,
#          'from': 180,
#          'numerous': 14,
#          'articles': 8,
#          'reviewing': 6,
#          'historical': 9,
#          'continuing': 11,
#          'publication': 3,
#          'journal': 10,
#          'special': 10,
#          'interest': 14,
#          'divisions': 1,
#          'division': 3,
#          'psychological': 95,
#          'there': 112,
#          'danger': 6,
#          'proclaiming': 1,
#          'an': 277,
#          'event': 18,
#          'or': 516,
#          'person': 26,
#          'historic': 1,
#          'father': 8,
#          'because': 74,
#          'proclamations': 1,
#          'may': 180,
#          'be': 490,
#          'challenged': 2,
#          'usually': 20,
#          'kindness': 1,
#          'always': 12,
#          'good': 41,
#          'humor': 2,
#          'other': 153,
#          'disciplines': 3,
#          'needs': 22,
#          'insights': 2,
#          'it': 330,
#          'understand': 31,
#          'whence': 1,
#          'came': 4,
#          'order': 24,
#          'assess': 24,
#          'where': 22,
#          'going': 6,
#          'perusal': 1,
#          'turn': 13,
#          'example': 54,
#          'spark': 1,
#          'concept': 10,
#          'long': 21,
#          'forgotten': 1,
#          'predecessor': 1,
#          'whose': 15,
#          'deserve': 1,
#          'revisited': 1,
#          'yet': 10,
#          'delving': 1,
#          'into': 53,
#          'works': 2,
#          'reminds': 1,
#          'false': 8,
#          'starts': 1,
#          'occasional': 1,
#          'damage': 14,
#          'they': 211,
#          'did': 39,
#          'henry': 3,
#          'goddard': 4,
#          'feeblemindedness': 2,
#          'during': 44,
#          'nineteeth': 1,
#          'self': 7,
#          'promotion': 1,
#          'hugo': 2,
#          'munsterberg': 12,
#          'however': 97,
#          'hindsight': 1,
#          'imperfect': 1,
#          'people': 26,
#          'sometimes': 20,
#          'overlooked': 4,
#          'discoveries': 1,
#          'incomplete': 1,
#          'thus': 31,
#          'approach': 36,
#          'once': 12,
#          'again': 10,
#          'humility': 1,
#          'paraphrase': 1,
#          'phrase': 3,
#          'journalism': 1,
#          'rough': 2,
#          'draft': 5,
#          'say': 11,
#          'here': 13,
#          'fourth': 3,
#          'emphasis': 11,
#          'its': 68,
#          'origins': 1,
#          'remains': 13,
#          'young': 9,
#          'branch': 1,
#          'applied': 11,
#          'having': 32,
#          'by': 381,
#          'apa': 22,
#          'recertified': 1,
#          'eight': 30,
#          'even': 45,
#          'ninety': 22,
#          'were': 186,
#          'adopted': 8,
#          'which': 202,
#          'forty': 17,
#          'recently': 9,
#          'renamed': 1,
#          'accepted': 5,
#          'council': 5,
#          'representatives': 2,
#          'interestingly': 5,
#          'although': 89,
#          'initially': 5,
#          'viewed': 3,
#          'primarily': 12,
#          'clinical': 95,
#          'nature': 44,
#          'assessments': 41,
#          'courts': 101,
#          'scope': 11,
#          'broadened': 2,
#          'encompass': 1,
#          'expertise': 11,
#          'very': 21,
#          'wide': 5,
#          'range': 21,
#          'contexts': 13,
#          'broad': 16,
#          'view': 10,
#          'supported': 4,
#          'according': 14,
#          'ronald': 1,
#          'roesch': 7,
#          'most': 113,
#          'define': 5,
#          'more': 157,
#          'narrowly': 6,
#          'refer': 3,
#          'engaged': 4,
#          'later': 20,
#          'brigham': 4,
#          'grisso': 12,
#          'modified': 1,
#          'somewhat': 6,
#          'noting': 4,
#          'many': 83,
#          'distinction': 7,
#          'between': 62,
#          'bring': 7,
#          'evaluate': 11,
#          'individuals': 37,
#          'testify': 16,
#          'them': 47,
#          'reference': 5,
#          'question': 43,
#          'recognizing': 2,
#          'itself': 4,
#          'narrow': 10,
#          'include': 52,
#          'assessment': 116,
#          'consultation': 12,
#          'noted': 34,
#          'take': 19,
#          'broader': 5,
#          'being': 59,
#          'broadly': 7,
#          'endeavor': 4,
#          'examines': 4,
#          'directly': 17,
#          'related': 54,
#          'process': 58,
#          'encompasses': 1,
#          'civil': 42,
#          'areas': 22,
#          'intersect': 1,
#          'therefore': 22,
#          'term': 18,
#          'refers': 11,
#          'production': 2,
#          'knowledge': 45,
#          'application': 8,
#          'systems': 14,
#          'includes': 12,
#          'activities': 9,
#          'varied': 2,
#          'courtroom': 17,
#          'child': 124,
#          'custody': 91,
#          'evaluations': 92,
#          'enforcement': 19,
#          'candidate': 2,
#          'screening': 26,
#          'facilities': 9,
#          'plaintiffs': 5,
#          'disability': 8,
#          'claims': 11,
#          'theory': 18,
#          'building': 4,
#          'design': 5,
#          'implementation': 1,
#          'intervention': 5,
#          'prevention': 1,
#          'youthful': 2,
#          'review': 39,
#          'table': 2,
#          'contents': 1,
#          'indicates': 8,
#          'similarly': 19,
#          'focus': 24,
#          'pages': 1,
#          'follow': 16,
#          'after': 38,
#          'introductory': 1,
#          'section': 33,
#          'covering': 4,
#          'seminal': 2,
#          'developments': 8,
#          'major': 15,
#          'undoubtedly': 3,
#          'considerable': 8,
#          'overlap': 2,
#          'categories': 11,
#          'subheadings': 1,
#          'jury': 40,
#          'least': 22,
#          'judge': 35,
#          'should': 145,
#          'know': 7,
#          'how': 65,
#          'far': 11,
#          'errors': 7,
#          'recollection': 2,
#          'normal': 2,
#          'vary': 15,
#          'under': 32,
#          'different': 38,
#          'conditions': 12,
#          'cattell': 4,
#          'himself': 10,
#          'surprised': 1,
#          'degree': 20,
#          'inaccuracy': 1,
#          'he': 113,
#          'uncovered': 1,
#          'individual': 46,
#          'differences': 28,
#          'levels': 16,
#          'confidence': 7,
#          'expressed': 4,
#          'students': 13,
#          'answers': 6,
#          'weather': 2,
#          'equally': 5,
#          'distributed': 1,
#          'all': 115,
#          'kinds': 6,
#          'possible': 35,
#          'beginning': 5,
#          'march': 1,
#          'nearly': 5,
#          'sure': 9,
#          'correct': 13,
#          'when': 114,
#          'while': 19,
#          'others': 31,
#          'consistently': 5,
#          'uncertain': 5,
#          'hesitant': 1,
#          'study': 28,
#          'probably': 5,
#          'genesis': 1,
#          'modern': 15,
#          'united': 49,
#          'states': 87,
#          'sparked': 1,
#          'researchers': 11,
#          'day': 11,
#          'dominant': 2,
#          'among': 29,
#          'joseph': 1,
#          'jastrow': 1,
#          'immediately': 4,
#          'replicated': 2,
#          'experiment': 2,
#          'university': 17,
#          'wisconsin': 5,
#          'obtained': 20,
#          'similar': 16,
#          'results': 31,
#          'aside': 2,
#          'brief': 17,
#          'flirtation': 1,
#          'embrace': 1,
#          'europe': 3,
#          'seemed': 2,
#          'intrigued': 1,
#          'interested': 18,
#          'concepts': 4,
#          'moreover': 7,
#          'found': 59,
#          'inaccuracies': 1,
#          'increased': 7,
#          'respect': 27,
#          'second': 21,
#          'half': 5,
#          'scenario': 10,
#          'excitement': 1,
#          'tension': 3,
#          'peak': 1,
#          'concluded': 16,
#          'tentatively': 1,
#          'affective': 2,
#          'reactions': 4,
#          'inhibit': 1,
#          'exact': 1,
#          'observation': 4,
#          'reliable': 9,
#          'remembrance': 1,
#          'own': 20,
#          'account': 6,
#          'stern': 5,
#          'basic': 11,
#          'than': 103,
#          'indeed': 22,
#          'i': 6,
#          'began': 13,
#          'examine': 5,
#          'correctness': 1,
#          'my': 1,
#          'determined': 11,
#          'theoretical': 5,
#          'interests': 23,
#          'realm': 2,
#          'memory': 7,
#          'rather': 37,
#          'any': 68,
#          'practical': 8,
#          'confronted': 1,
#          'realized': 3,
#          'importance': 15,
#          'beyond': 11,
#          'borders': 2,
#          'mere': 3,
#          'academic': 3,
#          'throughout': 8,
#          'decade': 2,
#          'active': 1,
#          'researcher': 6,
#          'helped': 5,
#          'establish': 12,
#          'edited': 4,
#          'betrage': 1,
#          'zur': 1,
#          'psychologie': 2,
#          'der': 1,
#          'aussage': 1,
#          'leipzig': 1,
#          'superseded': 4,
#          'seven': 36,
#          'much': 35,
#          'zeitschrift': 1,
#          'fur': 1,
#          'angewande': 1,
#          'otto': 3,
#          'lipmann': 1,
#          'cautionary': 1,
#          'note': 8,
#          'stressed': 4,
#          'witnesses': 20,
#          'intentionally': 2,
#          'falsify': 1,
#          'subtle': 1,
#          'common': 26,
#          'problem': 9,
#          'created': 5,
#          'unintentional': 1,
#          'falsification': 1,
#          'subjective': 6,
#          'sincerity': 1,
#          'does': 37,
#          'guarantee': 4,
#          'objective': 17,
#          'truthfulness': 2,
#          'wrote': 6,
#          'things': 11,
#          'leading': 6,
#          'suggestive': 1,
#          'questions': 47,
#          'contaminate': 1,
#          'accuracy': 16,
#          'eyewitness': 3,
#          'critical': 25,
#          'events': 24,
#          'adult': 7,
#          'lineups': 1,
#          'limited': 24,
#          'value': 8,
#          'members': 16,
#          'matched': 4,
#          'age': 8,
#          'physical': 11,
#          'appearance': 7,
#          'interceding': 1,
#          'recall': 2,
#          'can': 159,
#          'drastic': 1,
#          'effects': 16,
#          'empirical': 23,
#          'wundt': 1,
#          'philosopher': 1,
#          'experimentalist': 1,
#          'wary': 1,
#          'applying': 11,
#          'until': 13,
#          'sufficient': 19,
#          'conducted': 27,
#          'believed': 9,
#          'premature': 1,
#          'use': 77,
#          'partial': 3,
#          'could': 55,
#          'disastrous': 1,
#          'often': 32,
#          'took': 3,
#          'caveat': 2,
#          'quite': 12,
#          'seriously': 3,
#          'eventually': 7,
#          'link': 3,
#          'laboratory': 2,
#          'world': 7,
#          'outside': 1,
#          'willing': 1,
#          'give': 8,
#          'speeches': 1,
#          'gave': 7,
#          'inaugural': 1,
#          'lecture': 1,
#          'radcliffe': 1,
#          'college': 4,
#          'eighteen': 11,
#          'last': 4,
#          'same': 35,
#          'location': 3,
#          'sixteen': 7,
#          'suddenly': 1,
#          'died': 1,
#          'heart': 2,
#          'attack': 1,
#          'midsentence': 1,
#          'lecturing': 1,
#          'general': 42,
#          'class': 2,
#          'landy': 1,
#          'object': 1,
#          'scorn': 1,
#          'way': 29,
#          'ostracism': 1,
#          'less': 38,
#          'hardly': 1,
#          'ten': 13,
#          'dozens': 1,
#          'benjamin': 1,
#          'despised': 1,
#          'america': 4,
#          'recent': 26,
#          'article': 5,
#          'sporer': 1,
#          'correctly': 4,
#          'pointed': 7,
#          'out': 29,
#          'lost': 4,
#          'excessive': 3,
#          'bornstein': 2,
#          'penrod': 2,
#          'admirably': 1,
#          'compared': 15,
#          'respective': 4,
#          'texts': 3,
#          'arnold': 2,
#          'though': 11,
#          'academician': 1,
#          'displayed': 1,
#          'impressive': 3,
#          'familiarity': 2,
#          'literature': 27,
#          'style': 8,
#          'dry': 1,
#          'reads': 1,
#          'serious': 19,
#          'tome': 1,
#          'whereas': 31,
#          'directed': 1,
#          'audience': 2,
#          'commended': 1,
#          'bringing': 3,
#          'obscure': 1,
#          'fact': 42,
#          'overall': 6,
#          'reaching': 3,
#          'following': 20,
#          'year': 16,
#          'became': 12,
#          'assistant': 1,
#          'nine': 26,
#          'appointed': 5,
#          'associate': 2,
#          'professor': 7,
#          'teaching': 3,
#          'evidence': 74,
#          'appears': 10,
#          'qualify': 5,
#          'him': 23,
#          'psychologist': 101,
#          'granted': 4,
#          'faculty': 3,
#          'status': 16,
#          'school': 22,
#          'thirty': 38,
#          'slesinger': 1,
#          'followed': 8,
#          'hutchins': 1,
#          'chicago': 3,
#          'briefly': 6,
#          'dean': 1,
#          'several': 34,
#          'earlier': 19,
#          'william': 2,
#          'marston': 4,
#          'receive': 4,
#          'appointment': 5,
#          'influential': 4,
#          'associated': 25,
#          'era': 4,
#          'student': 4,
#          'mentor': 1,
#          'penchant': 1,
#          'alienating': 1,
#          'likely': 61,
#          'along': 7,
#          'lewis': 2,
#          'terman': 5,
#          'york': 8,
#          'city': 6,
#          'psychopathic': 2,
#          'clinic': 3,
#          'qualifies': 1,
#          'consultants': 8,
#          'using': 36,
#          'subjects': 7,
#          'simulated': 1,
#          'series': 13,
#          'studies': 51,
#          'written': 20,
#          'superior': 5,
#          'oral': 1,
#          'free': 12,
#          'narration': 1,
#          'complete': 15,
#          'accurate': 18,
#          'crossexamination': 1,
#          'direct': 13,
#          'questioning': 2,
#          'witness': 37,
#          'caution': 2,
#          'answering': 7,
#          'indicator': 1,
#          'female': 4,
#          'jurors': 67,
#          'considered': 36,
#          'carefully': 8,
#          'male': 3,
#          'rejected': 3,
#          'based': 80,
#          'test': 45,
#          'data': 84,
#          'twelveyearold': 1,
#          'alleged': 7,
#          'victim': 7,
#          'attempted': 6,
#          'rape': 1,
#          'moron': 1,
#          'presumptively': 1,
#          'agreeing': 2,
#          'trial': 88,
#          'court': 233,
#          'west': 4,
#          'virginia': 2,
#          'supreme': 52,
#          'demonstrated': 13,
#          'medical': 15,
#          'tests': 25,
#          'detect': 3,
#          'stand': 24,
#          'commentators': 9,
#          'interpreted': 10,
#          'driver': 1,
#          'loss': 4,
#          'wishing': 2,
#          'achieve': 6,
#          'louisell': 1,
#          'rejection': 1,
#          'per': 13,
#          'se': 9,
#          'particular': 36,
#          'offered': 11,
#          'nevertheless': 12,
#          'forties': 8,
#          'fifties': 6,
#          'testified': 6,
#          'regular': 6,
#          'basis': 27,
#          'jurisdictions': 24,
#          'presented': 23,
#          'relevant': 95,
#          'diverse': 2,
#          'influence': 11,
#          'pretrial': 8,
#          'publicity': 3,
#          'juries': 5,
#          'pornography': 1,
#          'adolescents': 2,
#          'effect': 24,
#          'certain': 27,
#          'educational': 8,
#          'practices': 8,
#          'children': 65,
#          'advertisements': 1,
#          'consumers': 1,
#          'widespread': 3,
#          'acceptance': 5,
#          'idea': 4,
#          'deserved': 3,
#          'niche': 1,
#          'resistance': 2,
#          'best': 42,
#          'cautious': 3,
#          'characterized': 9,
#          'post': 3,
#          'war': 1,
#          'appellate': 11,
#          'hand': 15,
#          'down': 4,
#          'rulings': 3,
#          'allowed': 9,
#          'offer': 13,
#          'issue': 68,
#          'mental': 144,
#          'responsibility': 27,
#          'tortious': 3,
#          'conduct': 50,
#          'loh': 2,
#          'attributed': 5,
#          'eventual': 2,
#          'increase': 10,
#          'professionalization': 1,
#          'rapid': 1,
#          'growth': 7,
#          'health': 85,
#          'professions': 3,
#          'period': 13,
#          'formulation': 4,
#          'doctrines': 1,
#          'insanity': 71,
#          'consistent': 19,
#          'psychiatry': 3,
#          'perhaps': 21,
#          'hawthorne': 2,
#          'michigan': 7,
#          'case': 238,
#          'tried': 1,
#          'murder': 11,
#          'wife': 5,
#          'lover': 1,
#          'pleaded': 1,
#          'guilty': 17,
#          'reason': 15,
#          'refused': 2,
#          'state': 111,
#          'doctoral': 4,
#          'list': 9,
#          'credentials': 3,
#          'finding': 17,
#          'erred': 1,
#          'accepting': 4,
#          'ruled': 5,
#          'standard': 50,
#          'determining': 21,
#          'extent': 19,
#          'advised': 3,
#          'merits': 2,
#          'claim': 9,
#          'ability': 16,
#          'presumed': 2,
#          'inferior': 1,
#          'man': 10,
#          'dissenters': 3,
#          'disease': 9,
#          'training': 23,
#          'hidden': 1,
#          'mutual': 2,
#          'life': 15,
#          'insurance': 9,
#          'co': 1,
#          'circuit': 16,
#          'appeals': 14,
#          'relating': 7,
#          'plaintiff': 97,
#          'argued': 16,
#          'disabling': 2,
#          'nervous': 1,
#          'condition': 17,
#          'prevented': 2,
#          'engaging': 3,
#          'gainful': 1,
#          'occupation': 1,
#          'entitled': 5,
#          'benefits': 14,
#          'administered': 8,
#          'battery': 6,
#          'projective': 2,
#          'behalf': 6,
#          'report': 57,
#          'lawyer': 10,
#          'company': 4,
#          'objected': 2,
#          'instructed': 2,
#          'disregard': 1,
#          'entire': 6,
#          'grounds': 10,
#          'express': 3,
#          ...})

# %%
counts_validation_set
# Out:
# Counter({'chapter': 18,
#          'five': 9,
#          'describes': 3,
#          'training': 8,
#          'models': 3,
#          'and': 641,
#          'resources': 2,
#          'in': 508,
#          'forensic': 69,
#          'psychology': 39,
#          'for': 191,
#          'faculty': 1,
#          'developing': 3,
#          'programs': 3,
#          'of': 783,
#          'instruction': 1,
#          'students': 11,
#          'general': 19,
#          'practitioners': 11,
#          'seeking': 2,
#          'specialized': 4,
#          'education': 6,
#          'or': 221,
#          'supervised': 2,
#          'experience': 11,
#          'part': 13,
#          'two': 29,
#          'comprises': 2,
#          'chapters': 5,
#          'concerning': 12,
#          'applications': 3,
#          'civil': 18,
#          'proceedings': 15,
#          'six': 12,
#          'addresses': 4,
#          'family': 7,
#          'law': 71,
#          'procedures': 7,
#          'issues': 28,
#          'related': 21,
#          'to': 615,
#          'conducting': 4,
#          'evaluations': 10,
#          'children': 25,
#          'their': 69,
#          'parents': 34,
#          'involved': 7,
#          'disputed': 1,
#          'custody': 16,
#          'twelve': 3,
#          'traces': 1,
#          'the': 1341,
#          'development': 3,
#          'current': 9,
#          'concepts': 3,
#          'criminal': 36,
#          'responsibility': 11,
#          'legal': 78,
#          'insanity': 30,
#          'thirteen': 2,
#          'delineates': 1,
#          'nuances': 1,
#          'intent': 5,
#          'diminished': 1,
#          'capacity': 4,
#          'four': 8,
#          'presents': 2,
#          'information': 49,
#          'on': 131,
#          'seven': 9,
#          'special': 4,
#          'fourteen': 3,
#          'leads': 2,
#          'off': 1,
#          'with': 146,
#          'a': 420,
#          'discussion': 4,
#          'violence': 48,
#          'risk': 73,
#          'research': 40,
#          'assessment': 42,
#          'fifteen': 3,
#          'follows': 1,
#          'an': 92,
#          'overview': 2,
#          'emerging': 1,
#          'roles': 6,
#          'psychologists': 63,
#          'enforcement': 5,
#          'sixteen': 2,
#          'reviews': 2,
#          'considerations': 6,
#          'evaluating': 4,
#          'jury': 14,
#          'decision': 20,
#          'making': 12,
#          'promoting': 1,
#          'juror': 2,
#          'competence': 15,
#          'seventeen': 2,
#          'eighteen': 5,
#          'review': 18,
#          'developments': 6,
#          'evaluation': 27,
#          'testimony': 38,
#          'given': 13,
#          'by': 114,
#          'adults': 5,
#          'whole': 1,
#          'however': 26,
#          'from': 61,
#          'nineteen': 27,
#          'eighties': 3,
#          'forward': 2,
#          'are': 162,
#          'addressed': 3,
#          'works': 1,
#          'other': 50,
#          'contributors': 2,
#          'this': 95,
#          'handbook': 1,
#          'refers': 1,
#          'psychological': 42,
#          'theory': 4,
#          'practice': 15,
#          'directly': 6,
#          'pertinent': 1,
#          'do': 32,
#          'horses': 1,
#          'field': 7,
#          'stand': 12,
#          'head': 2,
#          'tail': 1,
#          'wind': 1,
#          'which': 66,
#          'direction': 3,
#          'seeds': 1,
#          'apple': 1,
#          'point': 9,
#          'what': 25,
#          'was': 106,
#          'weather': 1,
#          'one': 74,
#          'week': 1,
#          'ago': 1,
#          'today': 1,
#          'when': 53,
#          'mckeen': 1,
#          'cattell': 3,
#          'posed': 3,
#          'these': 62,
#          'questions': 27,
#          'fifty': 7,
#          'college': 1,
#          'at': 51,
#          'columbia': 1,
#          'university': 2,
#          'march': 1,
#          'ninety': 10,
#          'three': 19,
#          'he': 40,
#          'probably': 2,
#          'first': 17,
#          'american': 15,
#          'studies': 7,
#          'albeit': 2,
#          'informal': 1,
#          'asked': 13,
#          'his': 71,
#          'were': 58,
#          'similar': 10,
#          'those': 26,
#          'that': 301,
#          'might': 13,
#          'naturally': 1,
#          'be': 152,
#          'court': 73,
#          'justice': 9,
#          'as': 170,
#          'we': 21,
#          'will': 30,
#          'see': 3,
#          'shortly': 3,
#          'both': 27,
#          'french': 1,
#          'german': 4,
#          'familiar': 2,
#          'powerful': 1,
#          'influence': 8,
#          'suggestion': 1,
#          'over': 12,
#          'sensation': 1,
#          'perception': 4,
#          'having': 7,
#          'conducted': 8,
#          'substantial': 5,
#          'areas': 11,
#          'specific': 20,
#          'conditions': 4,
#          'under': 9,
#          'inaccurate': 2,
#          'not': 117,
#          'known': 10,
#          'noted': 10,
#          'unscrupulous': 1,
#          'attorney': 15,
#          'can': 49,
#          'discredit': 1,
#          'statements': 6,
#          'truthful': 1,
#          'witness': 11,
#          'cunningly': 1,
#          'selected': 2,
#          'alfred': 1,
#          'binet': 2,
#          'replicated': 1,
#          'project': 2,
#          'france': 1,
#          'addition': 13,
#          'summarized': 1,
#          'relevant': 28,
#          'experiments': 3,
#          'being': 17,
#          'europe': 2,
#          'eventually': 2,
#          'called': 6,
#          'science': 2,
#          'psychojudiciaire': 1,
#          'stern': 5,
#          'liszt': 1,
#          'reality': 5,
#          'experiment': 1,
#          'class': 2,
#          'staging': 1,
#          'bogus': 1,
#          'quarrel': 1,
#          'between': 31,
#          'scientific': 11,
#          'controversy': 3,
#          'later': 6,
#          'recounted': 1,
#          'it': 101,
#          'argument': 3,
#          'accelerated': 1,
#          'until': 3,
#          'student': 2,
#          'drew': 1,
#          'revolver': 1,
#          'professor': 1,
#          'intervened': 1,
#          'written': 6,
#          'oral': 1,
#          'reports': 11,
#          'about': 61,
#          'aspects': 5,
#          'dispute': 5,
#          'among': 14,
#          'retained': 6,
#          'defense': 24,
#          'julian': 1,
#          'varendonck': 2,
#          'who': 57,
#          'designed': 6,
#          'series': 2,
#          'based': 33,
#          'suggested': 3,
#          'obtained': 3,
#          'preliminary': 1,
#          'hearing': 3,
#          'subjects': 2,
#          'approximately': 3,
#          'same': 10,
#          'age': 4,
#          'witnesses': 8,
#          'contrast': 4,
#          'believed': 3,
#          'errors': 4,
#          'recollection': 1,
#          'whether': 29,
#          'more': 50,
#          'reflection': 3,
#          'leading': 4,
#          'suggestive': 1,
#          'courtroom': 3,
#          'questioning': 3,
#          'than': 27,
#          'any': 33,
#          'natural': 1,
#          'tendency': 2,
#          'distort': 2,
#          'marbe': 4,
#          'became': 2,
#          'earliest': 3,
#          'european': 3,
#          'testify': 4,
#          'trial': 27,
#          'offering': 5,
#          'expert': 25,
#          'opinion': 15,
#          'issue': 16,
#          'reaction': 3,
#          'times': 9,
#          'applied': 13,
#          'train': 1,
#          'wreck': 1,
#          'near': 2,
#          'mullheim': 1,
#          'did': 9,
#          'case': 63,
#          'appears': 2,
#          'take': 5,
#          'credit': 2,
#          'paving': 1,
#          'way': 12,
#          'since': 5,
#          'time': 32,
#          'through': 7,
#          'my': 2,
#          'agency': 2,
#          'others': 7,
#          'mass': 1,
#          'has': 57,
#          'been': 50,
#          'submitted': 3,
#          'bearing': 1,
#          'continually': 2,
#          'upon': 6,
#          'new': 8,
#          'circumstances': 12,
#          'although': 35,
#          'mulberger': 2,
#          'wrote': 3,
#          'testifying': 3,
#          'courts': 38,
#          'even': 14,
#          'before': 8,
#          'is': 268,
#          'difficult': 7,
#          'find': 3,
#          'documentation': 1,
#          'they': 80,
#          'have': 75,
#          'along': 3,
#          'credited': 1,
#          'germany': 2,
#          'presumably': 1,
#          'slower': 1,
#          'recognizing': 1,
#          'key': 3,
#          'words': 3,
#          'likely': 19,
#          'respondent': 1,
#          'trying': 2,
#          'deceive': 2,
#          'barland': 1,
#          'reviewed': 6,
#          'history': 18,
#          'impressive': 1,
#          'detail': 3,
#          'notes': 2,
#          'approach': 10,
#          'catch': 1,
#          'because': 26,
#          'inefficient': 1,
#          'consuming': 1,
#          'often': 21,
#          'yielded': 1,
#          'inconclusive': 1,
#          'results': 10,
#          'turn': 1,
#          'twentieth': 2,
#          'century': 3,
#          'remained': 1,
#          'comparatively': 1,
#          'uninterested': 1,
#          'applying': 4,
#          'topics': 3,
#          'reason': 10,
#          'just': 3,
#          'beginning': 2,
#          'explore': 6,
#          'broad': 2,
#          'landscape': 1,
#          'had': 26,
#          'little': 7,
#          'inclination': 1,
#          'specialize': 1,
#          'matters': 15,
#          'reticence': 1,
#          'also': 30,
#          'due': 5,
#          'wilhelm': 1,
#          'wundt': 1,
#          'trained': 1,
#          'many': 21,
#          'pioneers': 1,
#          'leipzig': 1,
#          'laboratory': 2,
#          'munsterberg': 4,
#          'spent': 4,
#          'twenty': 12,
#          'years': 12,
#          'persuade': 2,
#          'public': 9,
#          'something': 1,
#          'offer': 7,
#          'virtually': 3,
#          'every': 6,
#          'area': 9,
#          'human': 3,
#          'endeavor': 1,
#          'claims': 3,
#          'exaggerated': 1,
#          'proposals': 1,
#          'rarely': 3,
#          'empirically': 2,
#          'usually': 4,
#          'published': 8,
#          'popular': 1,
#          'magazines': 1,
#          'rather': 10,
#          'scholarly': 3,
#          'journals': 2,
#          'incessantly': 1,
#          'promoted': 1,
#          'himself': 2,
#          'native': 1,
#          'alienated': 4,
#          'him': 8,
#          'increasingly': 1,
#          'colleagues': 3,
#          'world': 5,
#          'war': 4,
#          'i': 4,
#          'approached': 2,
#          'fact': 23,
#          'ardent': 1,
#          'progerman': 1,
#          'stance': 1,
#          'may': 62,
#          'much': 9,
#          'antipathy': 1,
#          'toward': 6,
#          'abrasive': 1,
#          'personality': 7,
#          'study': 15,
#          'group': 3,
#          'using': 12,
#          'harvard': 1,
#          'radcliffe': 1,
#          'titled': 1,
#          'mind': 8,
#          'juryman': 1,
#          'conclusion': 3,
#          'atypical': 2,
#          'stated': 8,
#          'psychologist': 32,
#          'satisfied': 1,
#          'system': 18,
#          'long': 4,
#          'women': 7,
#          'kept': 1,
#          'out': 11,
#          'finding': 2,
#          'female': 5,
#          'less': 15,
#          'accurate': 7,
#          'final': 3,
#          'decisions': 18,
#          'male': 4,
#          'interestingly': 2,
#          'own': 11,
#          'arrived': 2,
#          'very': 3,
#          'different': 10,
#          'nonetheless': 2,
#          'undeniably': 1,
#          'pushed': 1,
#          'reluctant': 2,
#          'into': 18,
#          'practical': 1,
#          'arena': 2,
#          'made': 17,
#          'seminal': 1,
#          'contribution': 3,
#          'particular': 17,
#          'placed': 2,
#          'abeyance': 1,
#          'most': 30,
#          'exploration': 2,
#          'early': 4,
#          'postwar': 1,
#          'saw': 1,
#          'few': 8,
#          'landmarks': 1,
#          'including': 18,
#          'gradual': 1,
#          'acceptance': 3,
#          'social': 13,
#          'scientists': 1,
#          'appointed': 3,
#          'school': 2,
#          'faculties': 1,
#          'during': 14,
#          'donald': 1,
#          'slesinger': 4,
#          'protege': 1,
#          'robert': 1,
#          'hutchins': 3,
#          'mark': 1,
#          'immediately': 2,
#          'following': 10,
#          'no': 17,
#          'formal': 4,
#          'acting': 3,
#          'dean': 1,
#          'year': 2,
#          'sterling': 1,
#          'fellow': 1,
#          'yale': 1,
#          'marston': 3,
#          'testified': 3,
#          'landmark': 2,
#          'frye': 8,
#          'set': 4,
#          'original': 2,
#          'standard': 11,
#          'federal': 19,
#          'continuing': 1,
#          'work': 14,
#          'lie': 2,
#          'detection': 2,
#          'represents': 2,
#          'major': 13,
#          'contributions': 2,
#          'means': 5,
#          'only': 31,
#          'frequently': 2,
#          'consulted': 2,
#          'attorneys': 13,
#          'police': 10,
#          'personnel': 1,
#          'evidence': 32,
#          'determinative': 1,
#          'acquittals': 1,
#          'several': 5,
#          'defendants': 24,
#          'accused': 6,
#          'murder': 2,
#          'background': 3,
#          'cautious': 1,
#          'style': 2,
#          'ideas': 4,
#          'acceptable': 2,
#          'community': 7,
#          'there': 33,
#          'put': 2,
#          'findings': 7,
#          'extensive': 2,
#          'use': 16,
#          'surprising': 2,
#          'some': 39,
#          'recommendations': 9,
#          'inapposite': 1,
#          'adversarial': 3,
#          'process': 26,
#          'united': 11,
#          'states': 31,
#          'would': 30,
#          'required': 12,
#          'fundamental': 6,
#          'changes': 4,
#          'discussed': 10,
#          'earlier': 7,
#          'cautioned': 1,
#          'experimental': 3,
#          'relevance': 2,
#          'inquisitorial': 1,
#          'used': 18,
#          'where': 9,
#          'neutral': 1,
#          'jurist': 1,
#          'period': 7,
#          'various': 13,
#          'reviewers': 1,
#          'took': 2,
#          'task': 3,
#          'documenting': 1,
#          'progress': 4,
#          'example': 27,
#          'coauthored': 1,
#          'numerous': 2,
#          'summary': 2,
#          'articles': 3,
#          'its': 14,
#          'status': 6,
#          'another': 18,
#          'article': 1,
#          'marion': 1,
#          'pilpel': 1,
#          'nine': 9,
#          'surveying': 1,
#          'forty': 5,
#          'eight': 6,
#          'relating': 2,
#          'appeared': 1,
#          'professional': 16,
#          'up': 8,
#          'eleven': 1,
#          'concerned': 4,
#          'ten': 6,
#          'deception': 2,
#          'intelligence': 5,
#          'crime': 9,
#          'behavior': 10,
#          'remainder': 1,
#          'focused': 4,
#          'such': 50,
#          'method': 3,
#          'like': 5,
#          'somewhat': 3,
#          'dormant': 1,
#          'wars': 1,
#          'regain': 1,
#          'energy': 1,
#          'late': 2,
#          'forties': 1,
#          'fifties': 1,
#          'scattered': 1,
#          'how': 23,
#          'juries': 2,
#          'formed': 3,
#          'opinions': 11,
#          'verdicts': 3,
#          'master': 1,
#          'thesis': 4,
#          'relationship': 14,
#          'narrative': 2,
#          'interrogative': 1,
#          'methods': 7,
#          'survey': 3,
#          'validity': 14,
#          'wigmore': 1,
#          'rules': 8,
#          'according': 4,
#          'loh': 1,
#          'interest': 11,
#          'twenties': 2,
#          'thirties': 2,
#          'thirty': 8,
#          'harold': 1,
#          'burtt': 3,
#          'possibly': 3,
#          'textbook': 3,
#          'disputing': 1,
#          'claim': 3,
#          'commented': 1,
#          'otto': 2,
#          'lipmann': 3,
#          'jurists': 1,
#          'truth': 4,
#          'depend': 1,
#          'meaning': 2,
#          'word': 1,
#          'clearly': 5,
#          'deserves': 1,
#          'compilation': 1,
#          'lectures': 1,
#          'gave': 2,
#          'studying': 1,
#          'book': 4,
#          'specifically': 5,
#          'intended': 4,
#          'educate': 1,
#          'future': 16,
#          'judges': 4,
#          'lawyers': 8,
#          'whereas': 7,
#          'nevertheless': 7,
#          'valuable': 3,
#          'academic': 3,
#          'literature': 1,
#          'discernible': 1,
#          'profession': 1,
#          'edward': 1,
#          'robinson': 2,
#          'predicted': 1,
#          'jurisprudence': 1,
#          'become': 5,
#          'sciences': 1,
#          'argued': 4,
#          'all': 31,
#          'must': 29,
#          'brought': 2,
#          'line': 1,
#          'knowledge': 11,
#          'lambasted': 1,
#          'essentially': 1,
#          'ignored': 1,
#          'hindsight': 1,
#          'scholars': 3,
#          'found': 17,
#          'palatable': 1,
#          'generally': 11,
#          'served': 1,
#          'but': 30,
#          'counterparts': 1,
#          'perhaps': 2,
#          'particularly': 8,
#          'included': 6,
#          'latter': 3,
#          'category': 1,
#          'juvenile': 4,
#          'hybrid': 1,
#          'dealing': 1,
#          'child': 50,
#          'protection': 3,
#          'delinquency': 1,
#          'consultation': 4,
#          'common': 13,
#          'inception': 1,
#          'discuss': 4,
#          'rogers': 1,
#          'visual': 1,
#          'routinely': 3,
#          'accepted': 7,
#          'trademark': 1,
#          'infringement': 1,
#          'cases': 34,
#          'cocacola': 1,
#          'company': 3,
#          'cherocola': 1,
#          'trademarks': 1,
#          'companies': 1,
#          'so': 18,
#          'cause': 9,
#          'confusion': 2,
#          'ultimately': 2,
#          'consumer': 1,
#          'apparently': 1,
#          'considered': 8,
#          'safe': 1,
#          'undertaking': 1,
#          'infringing': 1,
#          'territory': 1,
#          'medical': 2,
#          'experts': 6,
#          'physicians': 2,
#          'psychiatrists': 2,
#          'fewer': 2,
#          'onethird': 2,
#          'sixty': 2,
#          'percent': 15,
#          'accounts': 1,
#          'psychometrists': 1,
#          'keller': 2,
#          'described': 12,
#          'challenges': 1,
#          'faced': 3,
#          'december': 1,
#          'psychopathic': 1,
#          'established': 3,
#          'york': 4,
#          'city': 2,
#          'department': 4,
#          'express': 1,
#          'purpose': 5,
#          'examining': 5,
#          'persons': 16,
#          'detained': 1,
#          'staff': 5,
#          'neurologists': 1,
#          'workers': 1,
#          'whose': 3,
#          'conduct': 16,
#          'hasty': 1,
#          'pretrial': 2,
#          'consulting': 2,
#          'clinic': 1,
#          'detainees': 1,
#          'testing': 5,
#          'am': 1,
#          'disadvantage': 1,
#          'lack': 5,
#          'prisoners': 1,
#          'examined': 10,
#          'get': 4,
#          'them': 11,
#          'noon': 1,
#          'situated': 1,
#          'distant': 2,
#          'parts': 1,
#          'members': 3,
#          'prepare': 1,
#          'report': 14,
#          'help': 6,
#          'stanley': 1,
#          'hall': 1,
#          'goddard': 1,
#          'paved': 1,
#          'massive': 1,
#          'immigrants': 1,
#          'residents': 1,
#          'mental': 43,
#          'institutions': 1,
#          'prisons': 3,
#          'schools': 1,
#          'volume': 3,
#          'shartle': 1,
#          'prison': 7,
#          'administers': 1,
#          'aptitude': 1,
#          'tests': 5,
#          'either': 16,
#          'inmates': 3,
#          'certain': 12,
#          'groups': 2,
#          'depending': 1,
#          'institutional': 2,
#          'policy': 2,
#          'writes': 1,
#          'interpretation': 4,
#          'test': 19,
#          'prisoner': 1,
#          'records': 3,
#          'gives': 1,
#          'administrative': 2,
#          'officers': 6,
#          'specialists': 2,
#          'medicine': 1,
#          'psychiatry': 1,
#          'sociology': 1,
#          'occupational': 1,
#          'parole': 1,
#          'assists': 2,
#          'planning': 3,
#          'revising': 1,
#          'medically': 1,
#          'sponsored': 1,
#          'psychiatric': 8,
#          'severe': 1,
#          'physical': 8,
#          'disability': 2,
#          'sixties': 2,
#          'seventies': 2,
#          'exceptions': 1,
#          'correctional': 4,
#          'facilities': 1,
#          'classification': 1,
#          'treatment': 20,
#          'important': 32,
#          'proposed': 2,
#          'herbert': 1,
#          'quay': 1,
#          'marguerite': 1,
#          'warren': 1,
#          'predominant': 1,
#          'activity': 5,
#          'demand': 1,
#          'diagnostic': 6,
#          'services': 14,
#          'great': 6,
#          'obstacles': 2,
#          'relative': 4,
#          'respecting': 1,
#          'confidentiality': 4,
#          'achieving': 1,
#          'trust': 1,
#          'surmount': 1,
#          'exception': 3,
#          'bureau': 1,
#          'working': 2,
#          'reported': 3,
#          'organizational': 1,
#          'impediments': 1,
#          'meaningful': 3,
#          'assessments': 12,
#          'rehabilitation': 3,
#          'goal': 2,
#          'began': 1,
#          'gain': 2,
#          'favor': 2,
#          'certainly': 1,
#          'settings': 4,
#          'offenders': 8,
#          'providing': 10,
#          'ranks': 1,
#          'scored': 4,
#          'below': 1,
#          'average': 3,
#          'army': 2,
#          'alpha': 2,
#          'experienced': 1,
#          'officer': 1,
#          'lower': 4,
#          'score': 2,
#          'hundred': 10,
#          'patrol': 1,
#          'seventy': 4,
#          'sergeants': 1,
#          'averaged': 1,
#          'lieutenants': 1,
#          'thurstone': 1,
#          'concluded': 7,
#          'attract': 1,
#          'intelligent': 2,
#          'individuals': 18,
#          'entered': 2,
#          'service': 3,
#          'left': 1,
#          'occupations': 1,
#          'abilities': 10,
#          'better': 5,
#          'utilized': 2,
#          'vindicated': 1,
#          'maude': 1,
#          'merrill': 1,
#          'administered': 3,
#          'already': 2,
#          'employed': 2,
#          'applicants': 1,
#          'level': 14,
#          'blackburn': 1,
#          'criminological': 1,
#          'asserted': 3,
#          'growth': 3,
#          'number': 11,
#          'prominent': 1,
#          'burgeoning': 1,
#          'application': 1,
#          'last': 2,
#          'decades': 1,
#          'apparent': 2,
#          'parallel': 1,
#          'throughout': 3,
#          'indicators': 1,
#          'suggest': 4,
#          'extremely': 1,
#          'promising': 1,
#          'continue': 4,
#          'assess': 11,
#          'promise': 2,
#          'holds': 1,
#          'generation': 1,
#          'researchers': 3,
#          'practicing': 5,
#          'theorists': 1,
#          'past': 9,
#          'constitutional': 4,
#          'innovation': 2,
#          'creativity': 1,
#          'painstakingly': 1,
#          'relied': 2,
#          'arguments': 8,
#          'model': 5,
#          'adopted': 8,
#          'precedent': 1,
#          'encouraged': 4,
#          'bias': 3,
#          'self': 2,
#          'advocacy': 2,
#          'permitted': 2,
#          'heralded': 1,
#          'strengths': 2,
#          'indeed': 7,
#          'immediate': 2,
#          'concern': 5,
#          'driving': 1,
#          'force': 2,
#          'opposing': 3,
#          'victory': 1,
#          'attempts': 6,
#          'arrive': 1,
#          'variety': 6,
#          'diverse': 2,
#          'data': 28,
#          'gathering': 2,
#          'systematic': 2,
#          'collection': 3,
#          'attempt': 4,
#          'reduce': 7,
#          'error': 3,
#          'distortion': 1,
#          'observation': 4,
#          'inferences': 2,
#          'macro': 1,
#          'assist': 6,
#          'ways': 6,
#          'makers': 4,
#          'complicated': 3,
#          'otherwise': 2,
#          'assisting': 2,
#          'actors': 1,
#          'researching': 9,
#          'operation': 1,
#          'phenomena': 4,
#          'participation': 2,
#          'premise': 1,
#          'consider': 12,
#          'beyond': 4,
#          ...})

# %%
counts_test_set
# Out:
# Counter({'this': 121,
#          'fourth': 2,
#          'edition': 5,
#          'of': 873,
#          'the': 1484,
#          'handbook': 2,
#          'forensic': 82,
#          'psychology': 63,
#          'like': 5,
#          'its': 34,
#          'predecessors': 1,
#          'aims': 2,
#          'to': 632,
#          'provide': 29,
#          'an': 122,
#          'authoritative': 1,
#          'and': 596,
#          'comprehensive': 8,
#          'resource': 1,
#          'for': 202,
#          'understanding': 18,
#          'theoretical': 2,
#          'foundations': 2,
#          'becoming': 3,
#          'familiar': 7,
#          'with': 139,
#          'expanding': 1,
#          'research': 60,
#          'base': 1,
#          'in': 513,
#          'specialty': 10,
#          'learning': 4,
#          'apply': 3,
#          'concepts': 3,
#          'artfully': 1,
#          'everyday': 1,
#          'practice': 30,
#          'end': 5,
#          'contributors': 2,
#          'volume': 5,
#          'as': 176,
#          'prior': 17,
#          'three': 22,
#          'editions': 2,
#          'are': 134,
#          'accomplished': 2,
#          'scholars': 4,
#          'practitioners': 5,
#          'their': 83,
#          'respective': 1,
#          'areas': 16,
#          'some': 39,
#          'prominent': 2,
#          'academicians': 1,
#          'who': 58,
#          'conduct': 15,
#          'offer': 7,
#          'consultation': 6,
#          'others': 6,
#          'actively': 1,
#          'engaged': 3,
#          'service': 5,
#          'providers': 3,
#          'also': 50,
#          'make': 18,
#          'significant': 13,
#          'contributions': 3,
#          'literature': 14,
#          'several': 10,
#          'have': 89,
#          'degrees': 1,
#          'law': 89,
#          'well': 23,
#          'these': 75,
#          'authors': 8,
#          'were': 73,
#          'asked': 6,
#          'delineate': 2,
#          'enduring': 1,
#          'issues': 40,
#          'area': 7,
#          'frame': 1,
#          'light': 5,
#          'contemporary': 6,
#          'prevailing': 1,
#          'conceptual': 2,
#          'formations': 1,
#          'although': 34,
#          'similar': 8,
#          'focus': 16,
#          'structure': 7,
#          'previous': 5,
#          'present': 16,
#          'has': 61,
#          'been': 47,
#          'substantially': 4,
#          'rewritten': 1,
#          'updated': 2,
#          'enhance': 2,
#          'value': 6,
#          'content': 2,
#          'sequence': 1,
#          'chapters': 3,
#          'reframed': 1,
#          'increase': 3,
#          'relevance': 6,
#          'encompass': 1,
#          'both': 32,
#          'recent': 9,
#          'findings': 15,
#          'developments': 2,
#          'statutory': 4,
#          'case': 62,
#          'testimony': 29,
#          'fresh': 1,
#          'perspectives': 1,
#          'table': 3,
#          'contents': 1,
#          'identifies': 5,
#          'forty': 3,
#          'eight': 14,
#          'coauthors': 1,
#          'whom': 11,
#          'twenty': 23,
#          'four': 15,
#          'new': 12,
#          'comprises': 3,
#          'six': 12,
#          'parts': 3,
#          'part': 8,
#          'one': 50,
#          'concerns': 7,
#          'context': 11,
#          'begins': 2,
#          'on': 153,
#          'history': 10,
#          'defining': 2,
#          'nature': 16,
#          'chapter': 17,
#          'then': 15,
#          'provides': 10,
#          'information': 46,
#          'about': 65,
#          'guidelines': 14,
#          'accessing': 1,
#          'legal': 106,
#          'alerts': 1,
#          'psychologists': 68,
#          'ethical': 13,
#          'considerations': 8,
#          'that': 324,
#          'should': 54,
#          'guide': 8,
#          'work': 20,
#          'specific': 30,
#          'attention': 6,
#          'american': 8,
#          'psychological': 37,
#          'association': 4,
#          'ethics': 15,
#          'code': 17,
#          'seven': 8,
#          'discusses': 1,
#          'personal': 14,
#          'injury': 17,
#          'litigation': 8,
#          'particular': 13,
#          'assessment': 52,
#          'reviews': 2,
#          'impact': 9,
#          'congressional': 1,
#          'legislation': 4,
#          'identifying': 4,
#          'treating': 4,
#          'educational': 1,
#          'disabilities': 2,
#          'nine': 7,
#          'examines': 1,
#          'related': 15,
#          'persons': 9,
#          'competence': 18,
#          'execute': 2,
#          'a': 450,
#          'variety': 8,
#          'rights': 5,
#          'civil': 15,
#          'contexts': 8,
#          'ten': 7,
#          'concludes': 3,
#          'section': 13,
#          'conducting': 22,
#          'evaluations': 33,
#          'cases': 37,
#          'alleged': 9,
#          'child': 52,
#          'abuse': 7,
#          'or': 214,
#          'neglect': 1,
#          'deals': 1,
#          'applying': 6,
#          'criminal': 36,
#          'proceedings': 12,
#          'covers': 1,
#          'critical': 7,
#          'concern': 6,
#          'triers': 2,
#          'fact': 10,
#          'eleven': 4,
#          'assessing': 7,
#          'stand': 11,
#          'trial': 29,
#          'correctional': 5,
#          'example': 16,
#          'presupposes': 1,
#          'which': 73,
#          'we': 39,
#          'cover': 3,
#          'under': 10,
#          'is': 283,
#          'essential': 5,
#          'tool': 3,
#          'trade': 1,
#          'it': 118,
#          'underlies': 1,
#          'all': 29,
#          'nonetheless': 2,
#          'purposes': 3,
#          'historical': 3,
#          'trends': 1,
#          'landmarks': 1,
#          'discussion': 4,
#          'distinctive': 1,
#          'warranted': 2,
#          'rather': 7,
#          'than': 36,
#          'psychiatry': 3,
#          'own': 7,
#          'documented': 1,
#          'rich': 1,
#          'probably': 4,
#          'centered': 1,
#          'early': 4,
#          'isaac': 2,
#          'ray': 2,
#          'considered': 16,
#          'by': 138,
#          'father': 6,
#          'do': 29,
#          'not': 136,
#          'delve': 1,
#          'into': 18,
#          'origins': 3,
#          'sociology': 1,
#          'referred': 10,
#          'sociological': 1,
#          'jurisprudence': 2,
#          'realism': 2,
#          'movement': 2,
#          'within': 17,
#          'itself': 6,
#          'born': 1,
#          'during': 11,
#          'first': 24,
#          'third': 4,
#          'twentieth': 3,
#          'century': 5,
#          'advocated': 2,
#          'partnership': 1,
#          'between': 31,
#          'social': 5,
#          'sciences': 3,
#          'addition': 13,
#          'emphasize': 3,
#          'united': 11,
#          'states': 17,
#          'lesser': 3,
#          'extent': 8,
#          'oneanada': 1,
#          'give': 4,
#          'due': 4,
#          'recognition': 1,
#          'european': 3,
#          'dominated': 1,
#          'field': 4,
#          'world': 7,
#          'war': 4,
#          'i': 2,
#          'review': 16,
#          'achievements': 1,
#          'from': 56,
#          'nineteenth': 2,
#          'extend': 1,
#          'our': 9,
#          'nineteen': 24,
#          'seventies': 1,
#          'when': 48,
#          'came': 1,
#          'age': 4,
#          'reader': 2,
#          'interested': 6,
#          'more': 52,
#          'detail': 5,
#          'individuals': 17,
#          'discussed': 7,
#          'might': 15,
#          'check': 1,
#          'landmark': 2,
#          'summaries': 1,
#          'published': 12,
#          'whipple': 3,
#          'hutchins': 1,
#          'slesinger': 1,
#          'louisell': 2,
#          'tapp': 1,
#          'loh': 1,
#          'monahan': 6,
#          'loftus': 1,
#          'recently': 4,
#          'brigham': 2,
#          'grisso': 1,
#          'mulberger': 1,
#          'pieces': 2,
#          'topic': 8,
#          'latter': 4,
#          'strong': 1,
#          'emphasis': 1,
#          'german': 5,
#          'influences': 1,
#          'focuses': 4,
#          'psycholegal': 12,
#          'contacts': 1,
#          'judges': 9,
#          'lawyers': 3,
#          'other': 44,
#          'professionals': 14,
#          'wide': 3,
#          'range': 9,
#          'can': 65,
#          'be': 175,
#          'traced': 2,
#          'experimental': 2,
#          'europe': 3,
#          'particularly': 10,
#          'relation': 3,
#          'most': 35,
#          'children': 31,
#          'whose': 5,
#          'memory': 2,
#          'events': 8,
#          'was': 87,
#          'unreliable': 3,
#          'discuss': 2,
#          'shortly': 1,
#          'chestnut': 1,
#          'oak': 1,
#          'trees': 1,
#          'lose': 1,
#          'leaves': 1,
#          'earlier': 10,
#          'autumn': 1,
#          'his': 48,
#          'subjects': 1,
#          'allowed': 3,
#          'thirty': 10,
#          'seconds': 1,
#          'consider': 9,
#          'answers': 3,
#          'told': 4,
#          'write': 1,
#          'responses': 2,
#          'indicate': 4,
#          'degree': 6,
#          'confidence': 1,
#          'each': 15,
#          'answer': 2,
#          'cattell': 3,
#          'conducted': 10,
#          'informal': 2,
#          'preliminary': 2,
#          'study': 17,
#          'reasonably': 3,
#          'established': 6,
#          'eyewitness': 1,
#          'accounts': 4,
#          'incomplete': 2,
#          'development': 5,
#          'apparent': 2,
#          'fascination': 1,
#          'experiment': 1,
#          'binet': 1,
#          'held': 4,
#          'william': 2,
#          'stern': 3,
#          'had': 32,
#          'received': 6,
#          'doctorate': 1,
#          'at': 71,
#          'university': 4,
#          'berlin': 1,
#          'tutelage': 1,
#          'hermann': 1,
#          'ebbinghaus': 1,
#          'collaborated': 1,
#          'criminologist': 1,
#          'liszt': 1,
#          'attempt': 4,
#          'lend': 1,
#          'design': 2,
#          'witnesses': 8,
#          'students': 4,
#          'asserted': 1,
#          'known': 1,
#          'pitfalls': 1,
#          'testifying': 3,
#          'none': 2,
#          'could': 18,
#          'faultless': 1,
#          'report': 15,
#          'number': 12,
#          'errors': 1,
#          'per': 1,
#          'individual': 8,
#          'ranged': 3,
#          'twelve': 2,
#          'courtroom': 8,
#          'pinpointing': 1,
#          'easy': 1,
#          'sources': 21,
#          'differ': 3,
#          'often': 17,
#          'depending': 2,
#          'forum': 1,
#          'hale': 1,
#          'suggests': 3,
#          'earliest': 1,
#          'psychologist': 31,
#          'court': 89,
#          'occurred': 2,
#          'eighteen': 4,
#          'ninety': 9,
#          'albert': 1,
#          'von': 1,
#          'schrencknotzing': 4,
#          'testified': 5,
#          'munich': 1,
#          'man': 4,
#          'accused': 8,
#          'murdering': 1,
#          'women': 2,
#          'murders': 1,
#          'extensive': 3,
#          'sensational': 1,
#          'press': 3,
#          'coverage': 2,
#          'months': 2,
#          'opined': 1,
#          'pretrial': 1,
#          'publicity': 2,
#          'through': 13,
#          'process': 25,
#          'suggestion': 2,
#          'led': 3,
#          'numerous': 6,
#          'retroactive': 1,
#          'memoryfalsification': 1,
#          'distinguish': 2,
#          'what': 23,
#          'they': 83,
#          'seen': 4,
#          'reported': 8,
#          'happened': 1,
#          'supported': 1,
#          'opinion': 7,
#          'framework': 4,
#          'form': 6,
#          'laboratory': 3,
#          'suggestibility': 1,
#          'convicted': 4,
#          'basis': 8,
#          'solid': 2,
#          'evidence': 25,
#          'direct': 7,
#          'application': 4,
#          'processes': 5,
#          'helped': 1,
#          'stimulate': 1,
#          'interest': 6,
#          'jurists': 1,
#          'however': 25,
#          'karl': 1,
#          'marbe': 4,
#          'professor': 3,
#          'wurzburg': 2,
#          'credited': 1,
#          'himself': 2,
#          'appearance': 2,
#          'fifteen': 2,
#          'years': 10,
#          'later': 3,
#          'expert': 38,
#          'my': 1,
#          'sexual': 6,
#          'assault': 3,
#          'question': 10,
#          'adolescent': 2,
#          'girls': 2,
#          'teacher': 3,
#          'sexually': 1,
#          'molesting': 1,
#          'them': 12,
#          'persuaded': 1,
#          'jury': 10,
#          'statements': 4,
#          'exonerated': 1,
#          'belgian': 1,
#          'murder': 3,
#          'raping': 1,
#          'killing': 1,
#          'nineyearold': 1,
#          'girl': 1,
#          'two': 42,
#          'playmates': 1,
#          'apparently': 4,
#          'murderer': 1,
#          'but': 35,
#          'gave': 2,
#          'inconsistent': 1,
#          'contradictory': 4,
#          'he': 38,
#          'found': 22,
#          'inaccurate': 2,
#          'recall': 1,
#          'important': 27,
#          'over': 15,
#          'objection': 1,
#          'prosecution': 2,
#          'results': 12,
#          'experiments': 2,
#          'general': 23,
#          'available': 15,
#          'time': 26,
#          'wrote': 2,
#          'varendonck': 2,
#          'elicited': 1,
#          'violent': 11,
#          'outbursts': 1,
#          'authorities': 3,
#          'reached': 4,
#          'induced': 1,
#          'verdict': 17,
#          'guilty': 7,
#          'added': 5,
#          'way': 11,
#          'formally': 3,
#          'room': 2,
#          'saved': 1,
#          'life': 3,
#          'defendant': 56,
#          'noted': 10,
#          'vehemently': 2,
#          'opposed': 5,
#          'any': 23,
#          'use': 25,
#          'testify': 4,
#          'probable': 1,
#          'effect': 5,
#          'alcohol': 2,
#          'mental': 41,
#          'status': 1,
#          'engineer': 1,
#          'reaction': 4,
#          'fireman': 1,
#          'guard': 1,
#          'brakes': 1,
#          'based': 18,
#          'train': 1,
#          'stopped': 2,
#          'avert': 1,
#          'disaster': 1,
#          'essence': 2,
#          'difficult': 8,
#          'find': 8,
#          'illustrations': 1,
#          'nascent': 1,
#          'ranking': 1,
#          'chronologically': 1,
#          'must': 39,
#          'done': 4,
#          'caution': 5,
#          'turn': 6,
#          'until': 4,
#          'delving': 2,
#          'guilt': 2,
#          'deception': 3,
#          'precursor': 2,
#          'lie': 3,
#          'detection': 4,
#          'today': 3,
#          'germany': 1,
#          'austria': 1,
#          'switzerland': 1,
#          'busy': 1,
#          'developing': 1,
#          'test': 25,
#          'investigations': 1,
#          'word': 2,
#          'task': 4,
#          'key': 5,
#          'words': 4,
#          'embedded': 2,
#          'list': 5,
#          'innocuous': 2,
#          'wundt': 1,
#          'so': 20,
#          'cautious': 1,
#          'hugo': 1,
#          'munsterberg': 6,
#          'arrived': 2,
#          'invitation': 1,
#          'james': 1,
#          'harvard': 2,
#          'now': 6,
#          'acknowledged': 1,
#          'many': 16,
#          'applied': 11,
#          'believed': 1,
#          'knowledge': 21,
#          'education': 3,
#          'industry': 1,
#          'advertising': 1,
#          'music': 1,
#          'art': 1,
#          'course': 5,
#          'surprisingly': 2,
#          'community': 14,
#          'resisted': 1,
#          'intrusion': 2,
#          'territory': 1,
#          'there': 36,
#          'much': 10,
#          'ado': 1,
#          'charles': 1,
#          'c': 1,
#          'moore': 1,
#          'wellknown': 1,
#          'attorney': 15,
#          'yellow': 1,
#          'concluded': 7,
#          'provided': 9,
#          'nothing': 3,
#          'helpful': 5,
#          'noteworthy': 2,
#          'great': 1,
#          'commentator': 1,
#          'john': 2,
#          'henry': 2,
#          'wigmore': 3,
#          'necessary': 11,
#          'assail': 1,
#          'satirical': 1,
#          'devastating': 1,
#          'article': 2,
#          'attack': 2,
#          'prompted': 1,
#          'publication': 1,
#          'controversial': 2,
#          'bestseller': 1,
#          'witness': 8,
#          'proclaimed': 1,
#          'ripe': 1,
#          'practical': 1,
#          'needs': 13,
#          'system': 26,
#          'book': 3,
#          'essentially': 1,
#          'compilation': 2,
#          'already': 3,
#          'columns': 1,
#          'dealt': 1,
#          'spectrum': 2,
#          'topics': 5,
#          'ranging': 1,
#          'accuracy': 3,
#          'persuasion': 1,
#          'hypnosis': 1,
#          'fashion': 4,
#          'bornstein': 1,
#          'penrod': 1,
#          'sought': 1,
#          'resurrect': 1,
#          'longignored': 1,
#          'george': 1,
#          'frederick': 1,
#          'arnold': 1,
#          'servant': 1,
#          'british': 2,
#          'empire': 1,
#          'constructions': 2,
#          'before': 15,
#          'being': 15,
#          'opportunist': 1,
#          'trailblazer': 1,
#          'tempting': 1,
#          'blame': 1,
#          'brashness': 1,
#          'despicable': 1,
#          'demeanor': 1,
#          'progerman': 1,
#          'views': 2,
#          'tenuous': 1,
#          'occasionally': 1,
#          'hostile': 2,
#          'initial': 3,
#          'relationship': 6,
#          'phd': 1,
#          'marston': 3,
#          'interests': 11,
#          'multifaceted': 1,
#          'admitted': 2,
#          'massachusetts': 1,
#          'bar': 1,
#          'soon': 1,
#          'up': 6,
#          'concentrate': 2,
#          'assistant': 1,
#          'radcliffe': 1,
#          'college': 1,
#          'discovered': 2,
#          'positive': 1,
#          'correlation': 2,
#          'systolic': 1,
#          'blood': 1,
#          'pressure': 1,
#          'lying': 1,
#          'became': 3,
#          'modern': 3,
#          'polygraph': 1,
#          'almost': 2,
#          'exclusively': 3,
#          'produced': 2,
#          'such': 45,
#          'books': 3,
#          'lawyer': 5,
#          'foremost': 1,
#          'authority': 5,
#          'rules': 8,
#          'paved': 1,
#          'data': 22,
#          'observed': 4,
#          'psychometrist': 1,
#          'introducing': 1,
#          'would': 25,
#          'same': 12,
#          'footing': 1,
#          'insanity': 32,
#          'long': 3,
#          'tests': 7,
#          'recognized': 2,
#          'valid': 2,
#          'feasible': 3,
#          'scientific': 8,
#          'because': 34,
#          'records': 10,
#          'generally': 4,
#          'unavailable': 1,
#          'only': 28,
#          'appellate': 11,
#          'decisions': 24,
#          'may': 64,
#          'less': 13,
#          'rare': 3,
#          'paucity': 1,
#          'documentation': 3,
#          'know': 9,
#          'inevitably': 1,
#          'rejected': 2,
#          'involving': 3,
#          'state': 38,
#          'rule': 3,
#          'medical': 3,
#          'men': 3,
#          'licensed': 1,
#          'profession': 2,
#          'medicine': 1,
#          'experts': 8,
#          'propriety': 1,
#          'limitation': 1,
#          'too': 2,
#          'patent': 1,
#          'permit': 1,
#          'qualified': 1,
#          'appears': 3,
#          'driver': 3,
#          'occasion': 2,
#          'partial': 1,
#          'victory': 1,
#          'west': 1,
#          'virginia': 3,
#          'accepted': 5,
#          'chief': 1,
#          'bureau': 2,
#          'juvenile': 4,
#          'matter': 4,
#          'delinquency': 2,
#          'goddard': 1,
#          'hindsight': 1,
#          'regarded': 2,
#          'embarrassment': 1,
#          'interviews': 6,
#          'prisoner': 4,
#          'determine': 9,
#          'background': 2,
#          'attitudes': 5,
#          'personality': 6,
#          'traits': 4,
#          'guidance': 6,
#          'possibilities': 2,
#          'parole': 4,
#          'placement': 1,
#          'interview': 11,
#          'written': 7,
#          'submitted': 2,
#          'reports': 5,
#          'makes': 1,
#          'recommendations': 7,
#          'supplies': 1,
#          'technical': 1,
#          'staff': 3,
#          'meetings': 1,
#          'perhaps': 2,
#          'even': 17,
#          'relevant': 35,
#          'suspicion': 1,
#          'directed': 1,
#          'toward': 9,
#          'administrative': 5,
#          'staffs': 1,
#          'essay': 1,
#          'reviewing': 6,
#          'period': 1,
#          'brodsky': 2,
#          'cited': 4,
#          'examples': 2,
#          'military': 1,
#          'given': 17,
#          'punitive': 3,
#          'assignments': 1,
#          'civilian': 1,
#          'obstructed': 1,
#          'providing': 9,
#          'meaningful': 2,
#          'treatment': 20,
#          'services': 5,
#          'inmates': 2,
#          'reporting': 4,
#          'themselves': 3,
#          'no': 28,
#          'longer': 1,
#          'employed': 3,
#          'possessions': 1,
#          'waiting': 1,
#          'prison': 8,
#          'gate': 1,
#          'positions': 1,
#          'plentiful': 1,
#          'turnover': 1,
#          'rate': 8,
#          'high': 17,
#          'primarily': 3,
#          'adequate': 4,
#          'preparation': 1,
#          'responding': 1,
#          'unique': 10,
#          'challenges': 5,
#          'environments': 2,
#          'innovation': 1,
#          'introduced': 2,
#          'federal': 17,
#          'prisons': 1,
#          'era': 1,
#          'unit': 2,
#          'management': 10,
#          'initially': 4,
#          'conceptualized': 1,
#          'daniel': 1,
#          'glaser': 1,
#          'promoted': 1,
#          'robert': 2,
#          'levinson': 1,
#          'divided': 2,
#          'populations': 1,
#          'small': 6,
#          'groups': 3,
#          'prisoners': 1,
#          'members': 6,
#          'programming': 1,
#          'former': 2,
#          'expertise': 4,
#          'terman': 2,
#          'louis': 1,
#          'thurstone': 2,
#          'intellectual': 3,
#          'testing': 5,
#          'police': 2,
#          'screening': 8,
#          'administered': 4,
#          'newly': 1,
#          'developed': 10,
#          'army': 3,
#          'intelligence': 3,
#          'examination': 15,
#          'hundred': 5,
#          'fifty': 6,
#          'male': 2,
#          'detroit': 1,
#          'department': 2,
#          'alpha': 1,
#          'yerkes': 1,
#          'thorndike': 1,
#          'lewis': 2,
#          'adopted': 2,
#          'us': 4,
#          'seventeen': 4,
#          'wars': 2,
#          'gradually': 1,
#          'involved': 6,
#          'enforcement': 1,
#          'personnel': 3,
#          'began': 1,
#          'incorporate': 2,
#          'enterprise': 2,
#          'board': 6,
#          'certifications': 1,
#          'emerged': 2,
#          'examiners': 4,
#          'thousand': 8,
#          'apa': 6,
#          'voted': 1,
#          'recognize': 5,
#          'respectively': 2,
#          'rapid': 1,
#          'expansion': 1,
#          'globe': 1,
#          'besides': 1,
#          'north': 1,
#          'america': 1,
#          'australia': 1,
#          'after': 11,
#          'uncertain': 1,
#          'beginning': 4,
#          'stagnation': 1,
#          'despite': 5,
#          'continuing': 2,
#          'definition': 6,
#          'importantly': 1,
#          'clinical': 38,
#          'critically': 1,
#          'dependent': 2,
#          'theory': 4,
#          'indeed': 5,
#          'disagreement': 4,
#          'among': 13,
#          'apls': 1,
#          'how': 17,
#          'broad': 7,
#          'narrow': 3,
#          'group': 4,
#          'abandon': 1,
#          'cooperative': 1,
#          'effort': 2,
#          'academy': 1,
#          'jointly': 1,
#          'sponsor': 1,
#          'petition': 1,
#          'countries': 2,
#          'term': 2,
#          'expansive': 2,
#          'those': 42,
#          'typically': 14,
#          'regardless': 3,
#          'differences': 4,
#          'exist': 3,
#          'concerning': 7,
#          'uniformly': 1,
#          'agreed': 3,
#          'involves': 6,
#          'relies': 2,
#          'adversarial': 3,
#          'method': 6,
#          'whereas': 9,
#          'seeks': 2,
#          'justice': 5,
#          'equates': 1,
#          'procedural': 1,
#          'fairness': 2,
#          'hoped': 1,
#          'just': 7,
#          'procedures': 9,
#          'will': 25,
#          'assist': 10,
#          ...})

# %% [markdown]
# #### Save into text files named dictionary_freq

# %%
d1 = counts_train_set
json.dump(d1, open("dictionary_freq_trainset.txt",'w'))

d2 = counts_validation_set
json.dump(d2, open("dictionary_freq_validationset.txt",'w'))

d3 = counts_test_set
json.dump(d3, open("dictionary_freq_testset.txt",'w'))

# %%
# To read json
fd_1 = json.load(open("dictionary_freq_trainset.txt"))
fd_2 = json.load(open("dictionary_freq_validationset.txt"))
fd_3 = json.load(open("dictionary_freq_testset.txt"))

# %%
fd_1.items()
# Out:
# dict_items([('the', 4081), ('potential', 36), ('for', 598), ('psychologists', 200), ('to', 1835), ('assist', 33), ('legal', 284), ('system', 89), ('has', 170), ('been', 169), ('recognized', 7), ('since', 22), ('early', 34), ('twentieth', 10), ('century', 16), ('but', 121), ('only', 71), ('within', 35), ('past', 24), ('fifty', 25), ('years', 35), ('psychology', 176), ('begun', 3), ('realize', 1), ('this', 354), ('in', 1528), ('meaningful', 7), ('ways', 25), ('progress', 8), ('included', 21), ('newly', 2), ('developed', 33), ('professional', 65), ('organizations', 10), ('such', 151), ('as', 526), ('american', 32), ('law', 234), ('society', 12), ('and', 1952), ('international', 4), ('association', 14), ('correctional', 32), ('forensic', 231), ('graduate', 4), ('internship', 5), ('fellowship', 1), ('programs', 13), ('specialty', 28), ('area', 26), ('devoted', 9), ('certifying', 1), ('qualified', 7), ('practitioners', 26), ('board', 10), ('of', 2305), ('police', 53), ('public', 27), ('safety', 3), ('scientific', 18), ('journals', 11), ('human', 8), ('behavior', 41), ('behavioral', 11), ('sciences', 3), ('criminal', 92), ('justice', 28), ('books', 13), ('interface', 2), ('continued', 12), ('grow', 1), ('rapidly', 2), ('previous', 12), ('edition', 6), ('handbook', 8), ('was', 255), ('published', 28), ('two', 89), ('thousand', 24), ('six', 29), ('with', 428), ('increasing', 4), ('numbers', 2), ('becoming', 10), ('involved', 29), ('practice', 58), ('research', 148), ('a', 1163), ('steady', 2), ('flow', 2), ('new', 34), ('ideas', 4), ('information', 150), ('available', 39), ('chapters', 2), ('nineteen', 117), ('twenty', 62), ('then', 36), ('provide', 85), ('accounts', 6), ('development', 19), ('lie', 4), ('detection', 2), ('hypnosis', 1), ('describe', 14), ('current', 22), ('emerging', 2), ('trends', 5), ('uses', 3), ('these', 214), ('procedures', 31), ('part', 24), ('five', 43), ('looks', 2), ('at', 183), ('effective', 12), ('communication', 7), ('expert', 118), ('opinion', 39), ('cases', 117), ('chapter', 34), ('one', 192), ('focuses', 7), ('on', 373), ('essentials', 2), ('writing', 10), ('appropriate', 23), ('useful', 28), ('reports', 23), ('discusses', 3), ('admissibility', 3), ('testimony', 63), ('key', 12), ('considerations', 10), ('communicating', 1), ('work', 57), ('opinions', 51), ('decision', 80), ('makers', 9), ('concludes', 1), ('consideration', 17), ('some', 128), ('important', 76), ('aspects', 13), ('providing', 29), ('services', 49), ('offenders', 31), ('three', 63), ('principles', 15), ('rehabilitation', 7), ('both', 79), ('prison', 18), ('settings', 13), ('community', 22), ('four', 60), ('provides', 30), ('behind', 3), ('bars', 1), ('guide', 10), ('conducting', 40), ('psychotherapy', 4), ('continues', 2), ('theme', 1), ('specific', 63), ('attention', 20), ('diagnostic', 11), ('treatment', 60), ('working', 15), ('sexual', 19), ('finally', 18), ('appendix', 1), ('readers', 6), ('full', 9), ('text', 4), ('guidelines', 53), ('we', 86), ('would', 90), ('like', 33), ('thank', 1), ('our', 15), ('authors', 21), ('their', 324), ('valuable', 8), ('contributions', 12), ('volume', 5), ('those', 68), ('who', 132), ('revised', 12), ('that', 921), ('appeared', 3), ('editions', 5), ('joined', 3), ('us', 38), ('first', 81), ('time', 62), ('also', 94), ('want', 7), ('acknowledge', 3), ('appreciation', 5), ('guidance', 8), ('support', 32), ('john', 2), ('wiley', 1), ('sons', 1), ('editorial', 2), ('staff', 5), ('particularly', 21), ('patricia', 1), ('rossi', 1), ('executive', 4), ('editor', 2), ('kara', 1), ('borbely', 1), ('program', 6), ('coordinator', 5), ('recognize', 8), ('honor', 1), ('colleague', 3), ('allen', 1), ('hess', 2), ('served', 6), ('coeditor', 1), ('before', 34), ('his', 126), ('untimely', 1), ('death', 9), ('familiar', 11), ('will', 114), ('fingerprints', 1), ('well', 65), ('course', 17), ('over', 36), ('have', 243), ('learned', 6), ('few', 22), ('lessons', 2), ('asserted', 4), ('do', 66), ('not', 368), ('care', 11), (' ...

# %%
fd_2.items()
# Out:
# dict_items([('chapter', 18), ('five', 9), ('describes', 3), ('training', 8), ('models', 3), ('and', 641), ('resources', 2), ('in', 508), ('forensic', 69), ('psychology', 39), ('for', 191), ('faculty', 1), ('developing', 3), ('programs', 3), ('of', 783), ('instruction', 1), ('students', 11), ('general', 19), ('practitioners', 11), ('seeking', 2), ('specialized', 4), ('education', 6), ('or', 221), ('supervised', 2), ('experience', 11), ('part', 13), ('two', 29), ('comprises', 2), ('chapters', 5), ('concerning', 12), ('applications', 3), ('civil', 18), ('proceedings', 15), ('six', 12), ('addresses', 4), ('family', 7), ('law', 71), ('procedures', 7), ('issues', 28), ('related', 21), ('to', 615), ('conducting', 4), ('evaluations', 10), ('children', 25), ('their', 69), ('parents', 34), ('involved', 7), ('disputed', 1), ('custody', 16), ('twelve', 3), ('traces', 1), ('the', 1341), ('development', 3), ('current', 9), ('concepts', 3), ('criminal', 36), ('responsibility', 11), ('legal', 78), ('insanity', 30), ('thirteen', 2), ('delineates', 1), ('nuances', 1), ('intent', 5), ('diminished', 1), ('capacity', 4), ('four', 8), ('presents', 2), ('information', 49), ('on', 131), ('seven', 9), ('special', 4), ('fourteen', 3), ('leads', 2), ('off', 1), ('with', 146), ('a', 420), ('discussion', 4), ('violence', 48), ('risk', 73), ('research', 40), ('assessment', 42), ('fifteen', 3), ('follows', 1), ('an', 92), ('overview', 2), ('emerging', 1), ('roles', 6), ('psychologists', 63), ('enforcement', 5), ('sixteen', 2), ('reviews', 2), ('considerations', 6), ('evaluating', 4), ('jury', 14), ('decision', 20), ('making', 12), ('promoting', 1), ('juror', 2), ('competence', 15), ('seventeen', 2), ('eighteen', 5), ('review', 18), ('developments', 6), ('evaluation', 27), ('testimony', 38), ('given', 13), ('by', 114), ('adults', 5), ('whole', 1), ('however', 26), ('from', 61), ('nineteen', 27), ('eighties', 3), ('forward', 2), ('are', 162), ('addressed', 3), ('works', 1), ('other', 50), ('contributors', 2), ('this', 95), ('handbook', 1), ('refers', 1), ('psychological', 42), ('theory', 4), ('practice', 15), ('directly', 6), ('pertinent', 1), ('do', 32), ('horses', 1), ('field', 7), ('stand', 12), ('head', 2), ('tail', 1), ('wind', 1), ('which', 66), ('direction', 3), ('seeds', 1), ('apple', 1), ('point', 9), ('what', 25), ('was', 106), ('weather', 1), ('one', 74), ('week', 1), ('ago', 1), ('today', 1), ('when', 53), ('mckeen', 1), ('cattell', 3), ('posed', 3), ('these', 62), ('questions', 27), ('fifty', 7), ('college', 1), ('at', 51), ('columbia', 1), ('university', 2), ('march', 1), ('ninety', 10), ('three', 19), ('he', 40), ('probably', 2), ('first', 17), ('american', 15), ('studies', 7), ('albeit', 2), ('informal', 1), ('asked', 13), ('his', 71), ('were', 58), ('similar', 10), ('those', 26), ('that', 301), ('might', 13), ('naturally', 1), ('be', 152), ('court', 73), ('justice', 9), ('as', 170), ('we', 21), ('will', 30), ('see', 3), ('shortly', 3), ('both', 27), ('french', 1), ('german', 4), ('familiar', 2), ('powerful', 1), ('influence', 8), ('suggestion', 1), ('over', 12), ('sensation', 1), ('perception', 4), ('having', 7), ('conducted', 8), ('substantial', 5), ('areas', 11), ('specific', 20), ('conditions', 4), ('under', 9), ('inaccurate', 2), ('not', 117), ('known', 10), ('noted', 10), ('unscrupulous', 1), ('attorney', 15), ('can', 49), ('discredit', 1), ('statements', 6), ('truthful', 1), ('witness', 11), ('cunningly', 1), ('selected', 2), ('alfred', 1), ('binet', 2), ('replicated', 1), ('project', 2), ('france', 1), ('addition', 13), ('summarized', 1), ('relevant', 28), ('experiments', 3), ('being', 17), ('europe', 2), ('eventually', 2), ('called', 6), ('science', 2), ('psychojudiciaire', 1), ('stern', 5), ('liszt', 1), ('reality', 5), ('experiment', 1), ('class', 2), ('staging', 1), ('bogus', 1), ('quarrel', 1), ('between', 31), ('scientific', 11), ('controversy', 3), ('later', 6), ('recounted', 1), ('it', 101), ('argument', 3), ('accelerated', 1), ...

# %%
fd_3.items()
# Out:
# dict_items([('this', 121), ('fourth', 2), ('edition', 5), ('of', 873), ('the', 1484), ('handbook', 2), ('forensic', 82), ('psychology', 63), ('like', 5), ('its', 34), ('predecessors', 1), ('aims', 2), ('to', 632), ('provide', 29), ('an', 122), ('authoritative', 1), ('and', 596), ('comprehensive', 8), ('resource', 1), ('for', 202), ('understanding', 18), ('theoretical', 2), ('foundations', 2), ('becoming', 3), ('familiar', 7), ('with', 139), ('expanding', 1), ('research', 60), ('base', 1), ('in', 513), ('specialty', 10), ('learning', 4), ('apply', 3), ('concepts', 3), ('artfully', 1), ('everyday', 1), ('practice', 30), ('end', 5), ('contributors', 2), ('volume', 5), ('as', 176), ('prior', 17), ('three', 22), ('editions', 2), ('are', 134), ('accomplished', 2), ('scholars', 4), ('practitioners', 5), ('their', 83), ('respective', 1), ('areas', 16), ('some', 39), ('prominent', 2), ('academicians', 1), ('who', 58), ('conduct', 15), ('offer', 7), ('consultation', 6), ('others', 6), ('actively', 1), ('engaged', 3), ('service', 5), ('providers', 3), ('also', 50), ('make', 18), ('significant', 13), ('contributions', 3), ('literature', 14), ('several', 10), ('have', 89), ('degrees', 1), ('law', 89), ('well', 23), ('these', 75), ('authors', 8), ('were', 73), ('asked', 6), ('delineate', 2), ('enduring', 1), ('issues', 40), ('area', 7), ('frame', 1), ('light', 5), ('contemporary', 6), ('prevailing', 1), ('conceptual', 2), ('formations', 1), ('although', 34), ('similar', 8), ('focus', 16), ('structure', 7), ('previous', 5), ('present', 16), ('has', 61), ('been', 47), ('substantially', 4), ('rewritten', 1), ('updated', 2), ('enhance', 2), ('value', 6), ('content', 2), ('sequence', 1), ('chapters', 3), ('reframed', 1), ('increase', 3), ('relevance', 6), ('encompass', 1), ('both', 32), ('recent', 9), ('findings', 15), ('developments', 2), ('statutory', 4), ('case', 62), ('testimony', 29), ('fresh', 1), ('perspectives', 1), ('table', 3), ('contents', 1), ('identifies', 5), ('forty', 3), ('eight', 14), ('coauthors', 1), ('whom', 11), ('twenty', 23), ('four', 15), ('new', 12), ('comprises', 3), ('six', 12), ('parts', 3), ('part', 8), ('one', 50), ('concerns', 7), ('context', 11), ('begins', 2), ('on', 153), ('history', 10), ('defining', 2), ('nature', 16), ('chapter', 17), ('then', 15), ('provides', 10), ('information', 46), ('about', 65), ('guidelines', 14), ('accessing', 1), ('legal', 106), ('alerts', 1), ('psychologists', 68), ('ethical', 13), ('considerations', 8), ('that', 324), ('should', 54), ('guide', 8), ('work', 20), ('specific', 30), ('attention', 6), ('american', 8), ('psychological', 37), ('association', 4), ('ethics', 15), ('code', 17), ('seven', 8), ('discusses', 1), ('personal', 14), ('injury', 17), ('litigation', 8), ('particular', 13), ('assessment', 52), ('reviews', 2), ('impact', 9), ('congressional', 1), ('legislation', 4), ('identifying', 4), ('treating', 4), ('educational', 1), ('disabilities', 2), ('nine', 7), ('examines', 1), ('related', 15), ('persons', 9), ('competence', 18), ('execute', 2), ('a', 450), ('variety', 8), ('rights', 5), ('civil', 15), ('contexts', 8), ('ten', 7), ('concludes', 3), ('section', 13), ('conducting', 22), ('evaluations', 33), ('cases', 37), ('alleged', 9), ('child', 52), ('abuse', 7), ('or', 214), ('neglect', 1), ('deals', 1), ('applying', 6), ('criminal', 36), ('proceedings', 12), ('covers', 1), ('critical', 7), ('concern', 6), ('triers', 2), ('fact', 10), ('eleven', 4), ('assessing', 7), ('stand', 11), ('trial', 29), ('correctional', 5), ('example', 16), ('presupposes', 1), ('which', 73), ('we', 39), ('cover', 3), ('under', 10), ('is', 283), ('essential', 5), ('tool', 3), ('trade', 1), ('it', 118), ('underlies', 1), ('all', 29), ('nonetheless', 2), ('purposes', 3), ('historical', 3), ('trends', 1), ('landmarks', 1), ('discussion', 4), ('distinctive', 1), ('warranted', 2), ('rather', 7), ('than', 36), ('psychiatry', 3), ('own', 7), ('documented', 1), ('rich', 1), ('probably', 4), ('centered', 1 ...

# %% [markdown]
# ### Adding validation set into training set (combine frequency)

# %%
# Combined training set and validation set
fd_combined_set = d1 + d2

# %%
fd_combined_set
# Out:
# Counter({'the': 5422,
#          'potential': 48,
#          'for': 789,
#          'psychologists': 263,
#          'to': 2450,
#          'assist': 39,
#          'legal': 362,
#          'system': 107,
#          'has': 227,
#          'been': 219,
#          'recognized': 7,
#          'since': 27,
#          'early': 38,
#          'twentieth': 12,
#          'century': 19,
#          'but': 151,
#          'only': 102,
#          'within': 47,
#          'past': 33,
#          'fifty': 32,
#          'years': 47,
#          'psychology': 215,
#          'begun': 3,
#          'realize': 1,
#          'this': 449,
#          'in': 2036,
#          'meaningful': 10,
#          'ways': 31,
#          'progress': 12,
#          'included': 27,
#          'newly': 2,
#          'developed': 40,
#          'professional': 81,
#          'organizations': 14,
#          'such': 201,
#          'as': 696,
#          'american': 47,
#          'law': 305,
#          'society': 13,
#          'and': 2593,
#          'international': 4,
#          'association': 16,
#          'correctional': 36,
#          'forensic': 300,
#          'graduate': 4,
#          'internship': 5,
#          'fellowship': 1,
#          'programs': 16,
#          'specialty': 34,
#          'area': 35,
#          'devoted': 13,
#          'certifying': 1,
#          'qualified': 9,
#          'practitioners': 37,
#          'board': 12,
#          'of': 3088,
#          'police': 63,
#          'public': 36,
#          'safety': 5,
#          'scientific': 29,
#          'journals': 13,
#          'human': 11,
#          'behavior': 51,
#          'behavioral': 19,
#          'sciences': 4,
#          'criminal': 128,
#          'justice': 37,
#          'books': 14,
#          'interface': 2,
#          'continued': 15,
#          'grow': 1,
#          'rapidly': 5,
#          'previous': 14,
#          'edition': 7,
#          'handbook': 9,
#          'was': 361,
#          'published': 36,
#          'two': 118,
#          'thousand': 25,
#          'six': 41,
#          'with': 574,
#          'increasing': 4,
#          'numbers': 3,
#          'becoming': 10,
#          'involved': 36,
#          'practice': 73,
#          'research': 188,
#          'a': 1583,
#          'steady': 2,
#          'flow': 2,
#          'new': 42,
#          'ideas': 8,
#          'information': 199,
#          'available': 43,
#          'chapters': 7,
#          'nineteen': 144,
#          'twenty': 74,
#          'then': 42,
#          'provide': 106,
#          'accounts': 7,
#          'development': 22,
#          'lie': 6,
#          'detection': 4,
#          'hypnosis': 1,
#          'describe': 21,
#          'current': 31,
#          'emerging': 3,
#          'trends': 5,
#          'uses': 3,
#          'these': 276,
#          'procedures': 38,
#          'part': 37,
#          'five': 52,
#          'looks': 4,
#          'at': 234,
#          'effective': 12,
#          'communication': 8,
#          'expert': 143,
#          'opinion': 54,
#          'cases': 151,
#          'chapter': 52,
#          'one': 266,
#          'focuses': 9,
#          'on': 504,
#          'essentials': 2,
#          'writing': 13,
#          'appropriate': 26,
#          'useful': 35,
#          'reports': 34,
#          'discusses': 3,
#          'admissibility': 6,
#          'testimony': 101,
#          'key': 15,
#          'considerations': 16,
#          'communicating': 1,
#          'work': 71,
#          'opinions': 62,
#          'decision': 100,
#          'makers': 13,
#          'concludes': 1,
#          'consideration': 23,
#          'some': 167,
#          'important': 108,
#          'aspects': 18,
#          'providing': 39,
#          'services': 63,
#          'offenders': 39,
#          'three': 82,
#          'principles': 25,
#          'rehabilitation': 10,
#          'both': 106,
#          'prison': 25,
#          'settings': 17,
#          'community': 29,
#          'four': 68,
#          'provides': 35,
#          'behind': 4,
#          'bars': 2,
#          'guide': 13,
#          'conducting': 44,
#          'psychotherapy': 7,
#          'continues': 2,
#          'theme': 1,
#          'specific': 83,
#          'attention': 26,
#          'diagnostic': 17,
#          'treatment': 80,
#          'working': 17,
#          'sexual': 27,
#          'finally': 25,
#          'appendix': 1,
#          'readers': 8,
#          'full': 15,
#          'text': 5,
#          'guidelines': 62,
#          'we': 107,
#          'would': 120,
#          'like': 38,
#          'thank': 1,
#          'our': 24,
#          'authors': 22,
#          'their': 393,
#          'valuable': 11,
#          'contributions': 14,
#          'volume': 8,
#          'those': 94,
#          'who': 189,
#          'revised': 16,
#          'that': 1222,
#          'appeared': 4,
#          'editions': 5,
#          'joined': 3,
#          'us': 47,
#          'first': 98,
#          'time': 94,
#          'also': 124,
#          'want': 12,
#          'acknowledge': 4,
#          'appreciation': 6,
#          'guidance': 11,
#          'support': 39,
#          'john': 2,
#          'wiley': 1,
#          'sons': 1,
#          'editorial': 2,
#          'staff': 10,
#          'particularly': 29,
#          'patricia': 1,
#          'rossi': 1,
#          'executive': 5,
#          'editor': 2,
#          'kara': 1,
#          'borbely': 1,
#          'program': 9,
#          'coordinator': 5,
#          'recognize': 15,
#          'honor': 1,
#          'colleague': 4,
#          'allen': 1,
#          'hess': 4,
#          'served': 7,
#          'coeditor': 1,
#          'before': 42,
#          'his': 197,
#          'untimely': 1,
#          'death': 18,
#          'familiar': 13,
#          'will': 144,
#          'fingerprints': 1,
#          'well': 78,
#          'course': 19,
#          'over': 48,
#          'have': 318,
#          'learned': 6,
#          'few': 30,
#          'lessons': 2,
#          'asserted': 7,
#          'do': 98,
#          'not': 485,
#          'care': 15,
#          'about': 233,
#          'history': 65,
#          'profession': 11,
#          'are': 559,
#          'instead': 11,
#          'drawn': 8,
#          'contemporary': 11,
#          'issues': 108,
#          'theories': 8,
#          'simplistic': 1,
#          'generalization': 1,
#          'so': 53,
#          'subsequent': 12,
#          'acknowledged': 4,
#          'initial': 10,
#          'statement': 11,
#          'had': 99,
#          'rash': 1,
#          'is': 1016,
#          'apparent': 5,
#          'from': 241,
#          'numerous': 16,
#          'articles': 11,
#          'reviewing': 8,
#          'historical': 11,
#          'continuing': 12,
#          'publication': 3,
#          'journal': 10,
#          'special': 14,
#          'interest': 25,
#          'divisions': 1,
#          'division': 3,
#          'psychological': 137,
#          'there': 145,
#          'danger': 6,
#          'proclaiming': 1,
#          'an': 369,
#          'event': 22,
#          'or': 737,
#          'person': 43,
#          'historic': 1,
#          'father': 10,
#          'because': 100,
#          'proclamations': 1,
#          'may': 242,
#          'be': 642,
#          'challenged': 4,
#          'usually': 24,
#          'kindness': 1,
#          'always': 16,
#          'good': 47,
#          'humor': 2,
#          'other': 203,
#          'disciplines': 4,
#          'needs': 28,
#          'insights': 3,
#          'it': 431,
#          'understand': 49,
#          'whence': 1,
#          'came': 4,
#          'order': 32,
#          'assess': 35,
#          'where': 31,
#          'going': 6,
#          'perusal': 1,
#          'turn': 14,
#          'example': 81,
#          'spark': 1,
#          'concept': 15,
#          'long': 25,
#          'forgotten': 1,
#          'predecessor': 1,
#          'whose': 18,
#          'deserve': 1,
#          'revisited': 1,
#          'yet': 14,
#          'delving': 1,
#          'into': 71,
#          'works': 3,
#          'reminds': 1,
#          'false': 10,
#          'starts': 1,
#          'occasional': 1,
#          'damage': 24,
#          'they': 291,
#          'did': 48,
#          'henry': 3,
#          'goddard': 5,
#          'feeblemindedness': 2,
#          'during': 58,
#          'nineteeth': 1,
#          'self': 9,
#          'promotion': 1,
#          'hugo': 2,
#          'munsterberg': 16,
#          'however': 123,
#          'hindsight': 2,
#          'imperfect': 1,
#          'people': 33,
#          'sometimes': 23,
#          'overlooked': 4,
#          'discoveries': 1,
#          'incomplete': 1,
#          'thus': 39,
#          'approach': 46,
#          'once': 17,
#          'again': 11,
#          'humility': 1,
#          'paraphrase': 1,
#          'phrase': 3,
#          'journalism': 1,
#          'rough': 2,
#          'draft': 5,
#          'say': 14,
#          'here': 16,
#          'fourth': 5,
#          'emphasis': 12,
#          'its': 82,
#          'origins': 1,
#          'remains': 16,
#          'young': 11,
#          'branch': 1,
#          'applied': 24,
#          'having': 39,
#          'by': 495,
#          'apa': 23,
#          'recertified': 1,
#          'eight': 36,
#          'even': 59,
#          'ninety': 32,
#          'were': 244,
#          'adopted': 16,
#          'which': 268,
#          'forty': 22,
#          'recently': 17,
#          'renamed': 1,
#          'accepted': 12,
#          'council': 5,
#          'representatives': 3,
#          'interestingly': 7,
#          'although': 124,
#          'initially': 6,
#          'viewed': 6,
#          'primarily': 14,
#          'clinical': 119,
#          'nature': 62,
#          'assessments': 53,
#          'courts': 139,
#          'scope': 12,
#          'broadened': 2,
#          'encompass': 1,
#          'expertise': 13,
#          'very': 24,
#          'wide': 5,
#          'range': 26,
#          'contexts': 17,
#          'broad': 18,
#          'view': 12,
#          'supported': 4,
#          'according': 18,
#          'ronald': 1,
#          'roesch': 12,
#          'most': 143,
#          'define': 6,
#          'more': 207,
#          'narrowly': 6,
#          'refer': 4,
#          'engaged': 5,
#          'later': 26,
#          'brigham': 4,
#          'grisso': 13,
#          'modified': 4,
#          'somewhat': 9,
#          'noting': 5,
#          'many': 104,
#          'distinction': 10,
#          'between': 93,
#          'bring': 9,
#          'evaluate': 17,
#          'individuals': 55,
#          'testify': 20,
#          'them': 58,
#          'reference': 5,
#          'question': 50,
#          'recognizing': 3,
#          'itself': 5,
#          'narrow': 11,
#          'include': 57,
#          'assessment': 158,
#          'consultation': 16,
#          'noted': 44,
#          'take': 24,
#          'broader': 5,
#          'being': 76,
#          'broadly': 7,
#          'endeavor': 5,
#          'examines': 5,
#          'directly': 23,
#          'related': 75,
#          'process': 84,
#          'encompasses': 1,
#          'civil': 60,
#          'areas': 33,
#          'intersect': 1,
#          'therefore': 30,
#          'term': 21,
#          'refers': 12,
#          'production': 3,
#          'knowledge': 56,
#          'application': 9,
#          'systems': 16,
#          'includes': 15,
#          'activities': 11,
#          'varied': 6,
#          'courtroom': 20,
#          'child': 174,
#          'custody': 107,
#          'evaluations': 102,
#          'enforcement': 24,
#          'candidate': 2,
#          'screening': 28,
#          'facilities': 10,
#          'plaintiffs': 5,
#          'disability': 10,
#          'claims': 14,
#          'theory': 22,
#          'building': 5,
#          'design': 5,
#          'implementation': 1,
#          'intervention': 9,
#          'prevention': 2,
#          'youthful': 2,
#          'review': 57,
#          'table': 2,
#          'contents': 1,
#          'indicates': 8,
#          'similarly': 24,
#          'focus': 36,
#          'pages': 1,
#          'follow': 20,
#          'after': 46,
#          'introductory': 2,
#          'section': 39,
#          'covering': 4,
#          'seminal': 3,
#          'developments': 14,
#          'major': 28,
#          'undoubtedly': 4,
#          'considerable': 16,
#          'overlap': 5,
#          'categories': 12,
#          'subheadings': 1,
#          'jury': 54,
#          'least': 28,
#          'judge': 45,
#          'should': 201,
#          'know': 14,
#          'how': 88,
#          'far': 13,
#          'errors': 11,
#          'recollection': 3,
#          'normal': 2,
#          'vary': 17,
#          'under': 41,
#          'different': 48,
#          'conditions': 16,
#          'cattell': 7,
#          'himself': 12,
#          'surprised': 1,
#          'degree': 25,
#          'inaccuracy': 1,
#          'he': 153,
#          'uncovered': 1,
#          'individual': 62,
#          'differences': 32,
#          'levels': 19,
#          'confidence': 7,
#          'expressed': 6,
#          'students': 24,
#          'answers': 7,
#          'weather': 3,
#          'equally': 9,
#          'distributed': 1,
#          'all': 146,
#          'kinds': 8,
#          'possible': 47,
#          'beginning': 7,
#          'march': 2,
#          'nearly': 5,
#          'sure': 11,
#          'correct': 15,
#          'when': 167,
#          'while': 20,
#          'others': 38,
#          'consistently': 5,
#          'uncertain': 6,
#          'hesitant': 1,
#          'study': 43,
#          'probably': 7,
#          'genesis': 1,
#          'modern': 15,
#          'united': 60,
#          'states': 118,
#          'sparked': 1,
#          'researchers': 14,
#          'day': 16,
#          'dominant': 2,
#          'among': 43,
#          'joseph': 1,
#          'jastrow': 1,
#          'immediately': 6,
#          'replicated': 3,
#          'experiment': 3,
#          'university': 19,
#          'wisconsin': 6,
#          'obtained': 23,
#          'similar': 26,
#          'results': 41,
#          'aside': 3,
#          'brief': 19,
#          'flirtation': 1,
#          'embrace': 1,
#          'europe': 5,
#          'seemed': 2,
#          'intrigued': 1,
#          'interested': 20,
#          'concepts': 7,
#          'moreover': 13,
#          'found': 76,
#          'inaccuracies': 1,
#          'increased': 7,
#          'respect': 32,
#          'second': 26,
#          'half': 7,
#          'scenario': 16,
#          'excitement': 1,
#          'tension': 4,
#          'peak': 1,
#          'concluded': 23,
#          'tentatively': 1,
#          'affective': 5,
#          'reactions': 4,
#          'inhibit': 1,
#          'exact': 1,
#          'observation': 8,
#          'reliable': 13,
#          'remembrance': 1,
#          'own': 31,
#          'account': 6,
#          'stern': 10,
#          'basic': 12,
#          'than': 130,
#          'indeed': 29,
#          'i': 10,
#          'began': 14,
#          'examine': 6,
#          'correctness': 1,
#          'my': 3,
#          'determined': 17,
#          'theoretical': 5,
#          'interests': 27,
#          'realm': 2,
#          'memory': 9,
#          'rather': 47,
#          'any': 101,
#          'practical': 9,
#          'confronted': 2,
#          'realized': 3,
#          'importance': 18,
#          'beyond': 15,
#          'borders': 2,
#          'mere': 3,
#          'academic': 6,
#          'throughout': 11,
#          'decade': 3,
#          'active': 1,
#          'researcher': 6,
#          'helped': 5,
#          'establish': 15,
#          'edited': 4,
#          'betrage': 1,
#          'zur': 1,
#          'psychologie': 2,
#          'der': 1,
#          'aussage': 1,
#          'leipzig': 2,
#          'superseded': 4,
#          'seven': 45,
#          'much': 44,
#          'zeitschrift': 1,
#          'fur': 1,
#          'angewande': 1,
#          'otto': 5,
#          'lipmann': 4,
#          'cautionary': 1,
#          'note': 8,
#          'stressed': 5,
#          'witnesses': 28,
#          'intentionally': 2,
#          'falsify': 1,
#          'subtle': 1,
#          'common': 39,
#          'problem': 13,
#          'created': 5,
#          'unintentional': 1,
#          'falsification': 1,
#          'subjective': 8,
#          'sincerity': 1,
#          'does': 54,
#          'guarantee': 5,
#          'objective': 20,
#          'truthfulness': 2,
#          'wrote': 9,
#          'things': 16,
#          'leading': 10,
#          'suggestive': 2,
#          'questions': 74,
#          'contaminate': 1,
#          'accuracy': 18,
#          'eyewitness': 4,
#          'critical': 31,
#          'events': 32,
#          'adult': 7,
#          'lineups': 1,
#          'limited': 27,
#          'value': 11,
#          'members': 19,
#          'matched': 5,
#          'age': 12,
#          'physical': 19,
#          'appearance': 8,
#          'interceding': 1,
#          'recall': 2,
#          'can': 208,
#          'drastic': 1,
#          'effects': 17,
#          'empirical': 27,
#          'wundt': 2,
#          'philosopher': 1,
#          'experimentalist': 1,
#          'wary': 1,
#          'applying': 15,
#          'until': 16,
#          'sufficient': 25,
#          'conducted': 35,
#          'believed': 12,
#          'premature': 1,
#          'use': 93,
#          'partial': 5,
#          'could': 70,
#          'disastrous': 1,
#          'often': 53,
#          'took': 5,
#          'caveat': 2,
#          'quite': 15,
#          'seriously': 3,
#          'eventually': 9,
#          'link': 4,
#          'laboratory': 4,
#          'world': 12,
#          'outside': 4,
#          'willing': 2,
#          'give': 8,
#          'speeches': 1,
#          'gave': 9,
#          'inaugural': 1,
#          'lecture': 1,
#          'radcliffe': 2,
#          'college': 5,
#          'eighteen': 16,
#          'last': 6,
#          'same': 45,
#          'location': 4,
#          'sixteen': 9,
#          'suddenly': 1,
#          'died': 2,
#          'heart': 2,
#          'attack': 1,
#          'midsentence': 1,
#          'lecturing': 1,
#          'general': 61,
#          'class': 4,
#          'landy': 1,
#          'object': 2,
#          'scorn': 1,
#          'way': 41,
#          'ostracism': 1,
#          'less': 53,
#          'hardly': 2,
#          'ten': 19,
#          'dozens': 1,
#          'benjamin': 1,
#          'despised': 1,
#          'america': 5,
#          'recent': 37,
#          'article': 6,
#          'sporer': 1,
#          'correctly': 4,
#          'pointed': 8,
#          'out': 40,
#          'lost': 4,
#          'excessive': 3,
#          'bornstein': 2,
#          'penrod': 2,
#          'admirably': 1,
#          'compared': 21,
#          'respective': 4,
#          'texts': 5,
#          'arnold': 2,
#          'though': 14,
#          'academician': 1,
#          'displayed': 2,
#          'impressive': 4,
#          'familiarity': 2,
#          'literature': 28,
#          'style': 10,
#          'dry': 1,
#          'reads': 1,
#          'serious': 28,
#          'tome': 1,
#          'whereas': 38,
#          'directed': 1,
#          'audience': 2,
#          'commended': 1,
#          'bringing': 7,
#          'obscure': 1,
#          'fact': 65,
#          'overall': 10,
#          'reaching': 4,
#          'following': 30,
#          'year': 18,
#          'became': 14,
#          'assistant': 1,
#          'nine': 35,
#          'appointed': 8,
#          'associate': 2,
#          'professor': 8,
#          'teaching': 4,
#          'evidence': 106,
#          'appears': 12,
#          'qualify': 5,
#          'him': 31,
#          'psychologist': 133,
#          'granted': 7,
#          'faculty': 4,
#          'status': 22,
#          'school': 24,
#          'thirty': 46,
#          'slesinger': 5,
#          'followed': 10,
#          'hutchins': 4,
#          'chicago': 3,
#          'briefly': 6,
#          'dean': 2,
#          'several': 39,
#          'earlier': 26,
#          'william': 2,
#          'marston': 7,
#          'receive': 6,
#          'appointment': 5,
#          'influential': 4,
#          'associated': 30,
#          'era': 4,
#          'student': 6,
#          'mentor': 1,
#          'penchant': 1,
#          'alienating': 1,
#          'likely': 80,
#          'along': 10,
#          'lewis': 2,
#          'terman': 5,
#          'york': 12,
#          'city': 8,
#          'psychopathic': 3,
#          'clinic': 4,
#          'qualifies': 1,
#          'consultants': 9,
#          'using': 48,
#          'subjects': 9,
#          'simulated': 1,
#          'series': 15,
#          'studies': 58,
#          'written': 26,
#          'superior': 5,
#          'oral': 2,
#          'free': 16,
#          'narration': 1,
#          'complete': 16,
#          'accurate': 25,
#          'crossexamination': 2,
#          'direct': 16,
#          'questioning': 5,
#          'witness': 48,
#          'caution': 4,
#          'answering': 7,
#          'indicator': 1,
#          'female': 9,
#          'jurors': 71,
#          'considered': 44,
#          'carefully': 9,
#          'male': 7,
#          'rejected': 5,
#          'based': 113,
#          'test': 64,
#          'data': 112,
#          'twelveyearold': 1,
#          'alleged': 9,
#          'victim': 10,
#          'attempted': 7,
#          'rape': 3,
#          'moron': 1,
#          'presumptively': 1,
#          'agreeing': 2,
#          'trial': 115,
#          'court': 306,
#          'west': 5,
#          'virginia': 4,
#          'supreme': 70,
#          'demonstrated': 19,
#          'medical': 17,
#          'tests': 30,
#          'detect': 3,
#          'stand': 36,
#          'commentators': 10,
#          'interpreted': 13,
#          'driver': 1,
#          'loss': 6,
#          'wishing': 2,
#          'achieve': 6,
#          'louisell': 1,
#          'rejection': 3,
#          'per': 17,
#          'se': 12,
#          'particular': 53,
#          'offered': 14,
#          'nevertheless': 19,
#          'forties': 9,
#          'fifties': 7,
#          'testified': 9,
#          'regular': 6,
#          'basis': 36,
#          'jurisdictions': 37,
#          'presented': 32,
#          'relevant': 123,
#          'diverse': 4,
#          'influence': 19,
#          'pretrial': 10,
#          'publicity': 3,
#          'juries': 7,
#          'pornography': 1,
#          'adolescents': 2,
#          'effect': 26,
#          'certain': 39,
#          'educational': 8,
#          'practices': 10,
#          'children': 90,
#          'advertisements': 1,
#          'consumers': 1,
#          'widespread': 3,
#          'acceptance': 8,
#          'idea': 5,
#          'deserved': 3,
#          'niche': 1,
#          'resistance': 2,
#          'best': 51,
#          'cautious': 4,
#          'characterized': 11,
#          'post': 4,
#          'war': 5,
#          'appellate': 15,
#          'hand': 17,
#          'down': 5,
#          'rulings': 3,
#          'allowed': 11,
#          'offer': 20,
#          'issue': 84,
#          'mental': 187,
#          'responsibility': 38,
#          'tortious': 4,
#          'conduct': 66,
#          'loh': 3,
#          'attributed': 6,
#          'eventual': 2,
#          'increase': 12,
#          'professionalization': 1,
#          'rapid': 1,
#          'growth': 10,
#          'health': 108,
#          'professions': 3,
#          'period': 20,
#          'formulation': 6,
#          'doctrines': 1,
#          'insanity': 101,
#          'consistent': 22,
#          'psychiatry': 4,
#          'perhaps': 23,
#          'hawthorne': 2,
#          'michigan': 8,
#          'case': 301,
#          'tried': 1,
#          'murder': 13,
#          'wife': 5,
#          'lover': 1,
#          'pleaded': 1,
#          'guilty': 23,
#          'reason': 25,
#          'refused': 3,
#          'state': 139,
#          'doctoral': 4,
#          'list': 10,
#          'credentials': 3,
#          'finding': 19,
#          'erred': 1,
#          'accepting': 4,
#          'ruled': 9,
#          'standard': 61,
#          'determining': 25,
#          'extent': 27,
#          'advised': 4,
#          'merits': 3,
#          'claim': 12,
#          'ability': 27,
#          'presumed': 3,
#          'inferior': 1,
#          'man': 12,
#          'dissenters': 3,
#          'disease': 10,
#          'training': 31,
#          'hidden': 1,
#          'mutual': 2,
#          'life': 19,
#          'insurance': 9,
#          'co': 1,
#          'circuit': 19,
#          'appeals': 17,
#          'relating': 9,
#          'plaintiff': 126,
#          'argued': 20,
#          'disabling': 2,
#          'nervous': 1,
#          'condition': 21,
#          'prevented': 2,
#          'engaging': 3,
#          'gainful': 1,
#          'occupation': 1,
#          'entitled': 6,
#          'benefits': 15,
#          'administered': 11,
#          'battery': 6,
#          'projective': 2,
#          'behalf': 9,
#          'report': 71,
#          'lawyer': 11,
#          'company': 7,
#          'objected': 2,
#          'instructed': 3,
#          'disregard': 1,
#          'entire': 8,
#          'grounds': 12,
#          'express': 4,
#          ...})

# %%
json.dump(fd_combined_set, open("dictionary_freq_combinedset.txt",'w'))

# %%
fd_combine = json.load(open("dictionary_freq_combinedset.txt"))

# %%
fd_combine.items()
# Out:
# dict_items([('the', 5422), ('potential', 48), ('for', 789), ('psychologists', 263), ('to', 2450), ('assist', 39), ('legal', 362), ('system', 107), ('has', 227), ('been', 219), ('recognized', 7), ('since', 27), ('early', 38), ('twentieth', 12), ('century', 19), ('but', 151), ('only', 102), ('within', 47), ('past', 33), ('fifty', 32), ('years', 47), ('psychology', 215), ('begun', 3), ('realize', 1), ('this', 449), ('in', 2036), ('meaningful', 10), ('ways', 31), ('progress', 12), ('included', 27), ('newly', 2), ('developed', 40), ('professional', 81), ('organizations', 14), ('such', 201), ('as', 696), ('american', 47), ('law', 305), ('society', 13), ('and', 2593), ('international', 4), ('association', 16), ('correctional', 36), ('forensic', 300), ('graduate', 4), ('internship', 5), ('fellowship', 1), ('programs', 16), ('specialty', 34), ('area', 35), ('devoted', 13), ('certifying', 1), ('qualified', 9), ('practitioners', 37), ('board', 12), ('of', 3088), ('police', 63), ('public', 36), ('safety', 5), ('scientific', 29), ('journals', 13), ('human', 11), ('behavior', 51), ('behavioral', 19), ('sciences', 4), ('criminal', 128), ('justice', 37), ('books', 14), ('interface', 2), ('continued', 15), ('grow', 1), ('rapidly', 5), ('previous', 14), ('edition', 7), ('handbook', 9), ('was', 361), ('published', 36), ('two', 118), ('thousand', 25), ('six', 41), ('with', 574), ('increasing', 4), ('numbers', 3), ('becoming', 10), ('involved', 36), ('practice', 73), ('research', 188), ('a', 1583), ('steady', 2), ('flow', 2), ('new', 42), ('ideas', 8), ('information', 199), ('available', 43), ('chapters', 7), ('nineteen', 144), ('twenty', 74), ('then', 42), ('provide', 106), ('accounts', 7), ('development', 22), ('lie', 6), ('detection', 4), ('hypnosis', 1), ('describe', 21), ('current', 31), ('emerging', 3), ('trends', 5), ('uses', 3), ('these', 276), ('procedures', 38), ('part', 37), ('five', 52), ('looks', 4), ('at', 234), ('effective', 12), ('communication', 8), ('expert', 143), ('opinion', 54), ('cases', 151), ('chapter', 52), ('one', 266), ('focuses', 9), ('on', 504), ('essentials', 2), ('writing', 13), ('appropriate', 26), ('useful', 35), ('reports', 34), ('discusses', 3), ('admissibility', 6), ('testimony', 101), ('key', 15), ('considerations', 16), ('communicating', 1), ('work', 71), ('opinions', 62), ('decision', 100), ('makers', 13), ('concludes', 1), ('consideration', 23), ('some', 167), ('important', 108), ('aspects', 18), ('providing', 39), ('services', 63), ('offenders', 39), ('three', 82), ('principles', 25), ('rehabilitation', 10), ('both', 106), ('prison', 25), ('settings', 17), ('community', 29), ('four', 68), ('provides', 35), ('behind', 4), ('bars', 2), ('guide', 13), ('conducting', 44), ('psychotherapy', 7), ('continues', 2), ('theme', 1), ('specific', 83), ('attention', 26), ('diagnostic', 17), ('treatment', 80), ('working', 17), ('sexual', 27), ('finally', 25), ('appendix', 1), ('readers', 8), ('full', 15), ('text', 5), ('guidelines', 62), ('we', 107), ('would', 120), ('like', 38), ('thank', 1), ('our', 24), ('authors', 22), ('their', 393), ('valuable', 11), ('contributions', 14), ('volume', 8), ('those', 94), ('who', 189), ('revised', 16), ('that', 1222), ('appeared', 4), ('editions', 5), ('joined', 3), ('us', 47), ('first', 98), ('time', 94), ('also', 124), ('want', 12), ('acknowledge', 4), ('appreciation', 6), ('guidance', 11), ('support', 39), ('john', 2), ('wiley', 1), ('sons', 1), ('editorial', 2), ('staff', 10), ('particularly', 29), ('patricia', 1), ('rossi', 1), ('executive', 5), ('editor', 2), ('kara', 1), ('borbely', 1), ('program', 9), ('coordinator', 5), ('recognize', 15), ('honor', 1), ('colleague', 4), ('allen', 1), ('hess', 4), ('served', 7), ('coeditor', 1), ('before', 42), ('his', 197), ('untimely', 1), ('death', 18), ('familiar', 13), ('will', 144), ('fingerprints', 1), ('well', 78), ('course', 19), ('over', 48), ('have', 318), ('learned', 6), ('few', 30), ('lessons', 2), ('asserted', 7), ('do', 98), ('no ...
